# %%
# %run main.py
# Out:
# [KeOps] Warning : CUDA libraries not found or could not be loaded; Switching to CPU only.
# torch.Size([264, 2])
#
# ========= Round 0 =========
#
#
#  Computing The Best Response 0:
#
# Training V1 solution by HJB
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/IGT_GEN_Obstacl_D_new2/main.py in <module>
#     154
#     155 if __name__ == "__main__":
# --> 156     main()
#     157
#     158     # Restore stdout
#
# ~/IGT_GEN_Obstacl_D_new2/main.py in main()
#     120
#     121             an = Analytic(G_NN_list, Round, n, x0_ini, device, VV=1)
# --> 122             V_NN = train_v_nn(an, V_NN, args.num_epoch_v, args.num_epoch_hjb, t, args.lr_v, args.num_samples_hjb, args.num_samples_bvp, Round, device, VV=1)
#     123
#     124             t_tr, X_tr, t_OUT, X_OUT, x_out = sim_points(an, V_NN, args.num_samples_gen, args.N, args.t0, args.t_final, device)
#
# ~/IGT_GEN_Obstacl_D_new2/src/solve.py in train_v_nn(an, V_NN, num_epochs, num_epoch_hjb, t, lr_v, num_samples_hjb, num_samples_bvp, round_num, device, VV)
#     516
#     517     num_epoch_hjb = 1000
# --> 518     V_NN = Solve_HJB1(an, V_NN, num_epoch_hjb, t, lr_v, num_samples_hjb, device)
#     519
#     520     attempts, Ns_sol = 0, 0
#
# ~/IGT_GEN_Obstacl_D_new2/src/solve.py in Solve_HJB1(an, V_NN, num_epoch, t, lr, num_samples, device)
#      29         t = t.requires_grad_(True)
#      30
# ---> 31         V_nn =  V_NN(t, x_rand)
#      32
#      33         V_nn_t = torch.autograd.grad(outputs=V_nn, inputs=t,
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/IGT_GEN_Obstacl_D_new2/model.py in forward(self, t, inp)
#      28
#      29         out = torch.cat((t, inp), dim=1)
# ---> 30         out = self.act_func(self.lin1(out))
#      31         out = self.act_func(out + self.hh * self.lin2(out))
#      32         out = self.act_func(out + self.hh * self.lin3(out))
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     115
#     116     def forward(self, input: Tensor) -> Tensor:
# --> 117         return F.linear(input, self.weight, self.bias)
#     118
#     119     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1000x3 and 11x128)

# %%
# %run main.py
# Out:
# ========= Round 0 =========
#
#
# --- Step 0 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 5.2905e+01
# Iteration 1000: Loss = 6.3102e+00
# Iteration 2000: Loss = 1.7896e+00
# Iteration 3000: Loss = 6.7147e-01
# Iteration 4000: Loss = 2.9731e-01
# Iteration 5000: Loss = 1.0062e-01
#
#
# Generating data...
# Generated 10331 data from 32 BVP solutions in 24.4 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 3.2192e-02, Loss_V_x = 2.1002e-02, Loss_HJB = 2.8095e-01,  Loss_total = 3.3414e-01
# Iteration 1000: Loss_V = 4.9905e-04, Loss_V_x = 1.0943e-03, Loss_HJB = 7.3770e-03,  Loss_total = 8.9704e-03
# Iteration 2000: Loss_V = 1.6273e-04, Loss_V_x = 6.5639e-04, Loss_HJB = 3.9327e-03,  Loss_total = 4.7519e-03
# Iteration 3000: Loss_V = 4.6117e-05, Loss_V_x = 6.0693e-04, Loss_HJB = 2.0140e-03,  Loss_total = 2.6670e-03
# Iteration 4000: Loss_V = 1.2140e-05, Loss_V_x = 5.6899e-04, Loss_HJB = 1.1588e-03,  Loss_total = 1.7399e-03
# Iteration 5000: Loss_V = 2.4905e-05, Loss_V_x = 5.4047e-04, Loss_HJB = 1.0554e-03,  Loss_total = 1.6208e-03
#
#
# Generated 2688 data from 128 IVP solutions in 33.5 sec
#
# Iteration 0:  Loss_G = 1.0374e-01,  Loss_ODE = 2.2365e+00,  Loss_total = 1.2610e-01
# Iteration 1000:  Loss_G = 8.5001e-06,  Loss_ODE = 1.2298e-03,  Loss_total = 2.0798e-05
# Iteration 2000:  Loss_G = 4.5696e-06,  Loss_ODE = 6.5165e-04,  Loss_total = 1.1086e-05
# Iteration 3000:  Loss_G = 2.9838e-06,  Loss_ODE = 3.4776e-04,  Loss_total = 6.4614e-06
# Iteration 4000:  Loss_G = 4.0203e-06,  Loss_ODE = 3.6187e-04,  Loss_total = 7.6390e-06
# Iteration 5000:  Loss_G = 1.7348e-06,  Loss_ODE = 1.7208e-04,  Loss_total = 3.4556e-06
#
#
# Computed J: 2.399617
# Training V2 solution by HJB
# Iteration 0: Loss = 1.1573e+00
# Iteration 1000: Loss = 2.1063e-02
# Iteration 2000: Loss = 1.2632e-02
# Iteration 3000: Loss = 1.3260e-02
# Iteration 4000: Loss = 1.0397e-02
# Iteration 5000: Loss = 5.8890e-03
#
#
# Generating data...
# Generated 3247 data from 32 BVP solutions in 21.6 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 1.4806e-04, Loss_V_x = 2.6072e-03, Loss_HJB = 1.8373e-02,  Loss_total = 2.1128e-02
# Iteration 1000: Loss_V = 3.1053e-05, Loss_V_x = 2.5348e-04, Loss_HJB = 4.5184e-03,  Loss_total = 4.8029e-03
# Iteration 2000: Loss_V = 1.4153e-05, Loss_V_x = 1.7126e-04, Loss_HJB = 2.4168e-03,  Loss_total = 2.6022e-03
# Iteration 3000: Loss_V = 1.7147e-05, Loss_V_x = 1.7842e-04, Loss_HJB = 3.0260e-03,  Loss_total = 3.2216e-03
# Iteration 4000: Loss_V = 1.2937e-05, Loss_V_x = 1.4777e-04, Loss_HJB = 2.3191e-03,  Loss_total = 2.4798e-03
# Iteration 5000: Loss_V = 3.3302e-05, Loss_V_x = 1.5121e-04, Loss_HJB = 1.7899e-03,  Loss_total = 1.9744e-03
#
#
# Generated 2688 data from 128 IVP solutions in 32.4 sec
#
# Iteration 0:  Loss_G = 3.7155e-02,  Loss_ODE = 1.9781e+00,  Loss_total = 5.6936e-02
# Iteration 1000:  Loss_G = 9.3728e-06,  Loss_ODE = 1.1456e-03,  Loss_total = 2.0829e-05
# Iteration 2000:  Loss_G = 7.3962e-06,  Loss_ODE = 6.9092e-04,  Loss_total = 1.4305e-05
# Iteration 3000:  Loss_G = 3.9827e-06,  Loss_ODE = 3.5024e-04,  Loss_total = 7.4851e-06
# Iteration 4000:  Loss_G = 3.0019e-06,  Loss_ODE = 2.3996e-04,  Loss_total = 5.4015e-06
# Iteration 5000:  Loss_G = 8.7407e-06,  Loss_ODE = 4.5173e-04,  Loss_total = 1.3258e-05
#
#
# Computed V0: 1.341953
# Exploitability: 1.057663
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 1.5114e+01
# L2 norm    : 3.5494e+00
# Linf norm  : 1.0134e+00
# ==============================================
#
# Step Time: 345.7 sec
#
#
# --- Step 1 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 2.8537e-01
# Iteration 1000: Loss = 2.5157e-03
# Iteration 2000: Loss = 1.5892e-03
# Iteration 3000: Loss = 9.7037e-04
# Iteration 4000: Loss = 1.0830e-03
# Iteration 5000: Loss = 8.7332e-04
#
#
# Generating data...
# Solver failed (1/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.7325e-03
# Iteration 1000: Loss = 9.0759e-04
#
#
# Solver failed (2/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.5353e-03
# Iteration 1000: Loss = 6.7259e-04
#
#
# Solver failed (3/26): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.4838e-03
# Iteration 1000: Loss = 6.9085e-04
#
#
# Solver failed (4/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7186e-03
# Iteration 1000: Loss = 4.2735e-04
#
#
# Solver failed (5/20): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.8664e-03
# Iteration 1000: Loss = 5.9429e-04
#
#
# Solver failed (6/20): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.4999e-03
# Iteration 1000: Loss = 6.5076e-04
#
#
# Solver failed (7/20): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.3259e-03
# Iteration 1000: Loss = 4.3263e-04
#
#
# Solver failed (8/16): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.7102e-03
# Iteration 1000: Loss = 7.6052e-04
#
#
# Solver failed (9/13): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.1181e-03
# Iteration 1000: Loss = 5.3957e-04
#
#
# Solver failed (10/13): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7560e-03
# Iteration 1000: Loss = 5.7532e-04
#
#
# Solver failed (11/6): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 13781 data from 26 BVP solutions in 161.4 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 3.2883e-05, Loss_V_x = 2.5626e-03, Loss_HJB = 1.7322e-03,  Loss_total = 4.3277e-03
# Iteration 1000: Loss_V = 1.3179e-05, Loss_V_x = 8.8569e-04, Loss_HJB = 7.5350e-04,  Loss_total = 1.6524e-03
# Iteration 2000: Loss_V = 1.0948e-05, Loss_V_x = 7.9014e-04, Loss_HJB = 5.6738e-04,  Loss_total = 1.3685e-03
# Iteration 3000: Loss_V = 1.0507e-05, Loss_V_x = 6.6810e-04, Loss_HJB = 8.5380e-04,  Loss_total = 1.5324e-03
# Iteration 4000: Loss_V = 9.1858e-06, Loss_V_x = 6.0497e-04, Loss_HJB = 6.1276e-04,  Loss_total = 1.2269e-03
# Iteration 5000: Loss_V = 2.2315e-05, Loss_V_x = 5.3250e-04, Loss_HJB = 4.2819e-04,  Loss_total = 9.8300e-04
#
#
# Generated 2688 data from 128 IVP solutions in 38.7 sec
#
# Iteration 0:  Loss_G = 9.0633e-02,  Loss_ODE = 4.4461e-01,  Loss_total = 9.5079e-02
# Iteration 1000:  Loss_G = 1.3499e-05,  Loss_ODE = 2.0703e-03,  Loss_total = 3.4202e-05
# Iteration 2000:  Loss_G = 6.6441e-06,  Loss_ODE = 8.6694e-04,  Loss_total = 1.5313e-05
# Iteration 3000:  Loss_G = 4.6062e-06,  Loss_ODE = 4.8466e-04,  Loss_total = 9.4528e-06
# Iteration 4000:  Loss_G = 3.9919e-06,  Loss_ODE = 3.6428e-04,  Loss_total = 7.6347e-06
# Iteration 5000:  Loss_G = 2.8059e-06,  Loss_ODE = 1.6562e-04,  Loss_total = 4.4621e-06
#
#
# Computed J: 2.092826
# Training V2 solution by HJB
# Iteration 0: Loss = 1.6092e-01
# Iteration 1000: Loss = 4.9306e-03
# Iteration 2000: Loss = 3.4989e-03
# Iteration 3000: Loss = 2.7688e-03
# Iteration 4000: Loss = 2.5715e-03
# Iteration 5000: Loss = 1.6374e-03
#
#
# Generating data...
# Solver failed (1/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.9678e-03
# Iteration 1000: Loss = 2.7949e-03
#
#
# Solver failed (2/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.3781e-03
# Iteration 1000: Loss = 1.4223e-03
#
#
# Generated 7843 data from 32 BVP solutions in 59.2 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 3.3097e-04, Loss_V_x = 1.1125e-02, Loss_HJB = 9.9701e-03,  Loss_total = 2.1427e-02
# Iteration 1000: Loss_V = 2.6107e-05, Loss_V_x = 1.1191e-03, Loss_HJB = 3.9770e-03,  Loss_total = 5.1222e-03
# Iteration 2000: Loss_V = 1.6385e-05, Loss_V_x = 1.1588e-03, Loss_HJB = 2.5520e-03,  Loss_total = 3.7272e-03
# Iteration 3000: Loss_V = 2.9782e-05, Loss_V_x = 8.7912e-04, Loss_HJB = 2.0292e-03,  Loss_total = 2.9381e-03
# Iteration 4000: Loss_V = 1.2461e-05, Loss_V_x = 8.2869e-04, Loss_HJB = 2.1660e-03,  Loss_total = 3.0071e-03
# Iteration 5000: Loss_V = 1.0998e-05, Loss_V_x = 7.2552e-04, Loss_HJB = 1.8557e-03,  Loss_total = 2.5922e-03
#
#
# Generated 2688 data from 128 IVP solutions in 40.3 sec
#
# Iteration 0:  Loss_G = 4.1579e-01,  Loss_ODE = 3.2744e+00,  Loss_total = 4.4854e-01
# Iteration 1000:  Loss_G = 3.2319e-05,  Loss_ODE = 4.4137e-03,  Loss_total = 7.6455e-05
# Iteration 2000:  Loss_G = 1.6400e-05,  Loss_ODE = 1.9202e-03,  Loss_total = 3.5602e-05
# Iteration 3000:  Loss_G = 2.4733e-05,  Loss_ODE = 1.8494e-03,  Loss_total = 4.3227e-05
# Iteration 4000:  Loss_G = 2.8401e-05,  Loss_ODE = 1.4531e-03,  Loss_total = 4.2932e-05
# Iteration 5000:  Loss_G = 5.6678e-06,  Loss_ODE = 6.9888e-04,  Loss_total = 1.2657e-05
#
#
# Computed V0: 1.601405
# Exploitability: 0.491421
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 1.3136e+01
# L2 norm    : 3.0934e+00
# Linf norm  : 8.8645e-01
# ==============================================
#
# Step Time: 558.6 sec
#
#
# --- Step 2 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 6.6684e-02
# Iteration 1000: Loss = 1.0069e-03
# Iteration 2000: Loss = 5.7514e-04
# Iteration 3000: Loss = 6.0977e-04
# Iteration 4000: Loss = 4.8476e-04
# Iteration 5000: Loss = 4.4425e-04
#
#
# Generating data...
# Solver failed (1/32): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.7122e-03
# Iteration 1000: Loss = 5.7330e-04
#
#
# Solver failed (2/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.2508e-03
# Iteration 1000: Loss = 5.2168e-04
#
#
# Solver failed (3/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6831e-03
# Iteration 1000: Loss = 5.2151e-04
#
#
# Solver failed (4/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.8707e-03
# Iteration 1000: Loss = 4.6885e-04
#
#
# Solver failed (5/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.2260e-03
# Iteration 1000: Loss = 4.2228e-04
#
#
# Solver failed (6/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1581e-02
# Iteration 1000: Loss = 4.2146e-04
#
#
# Solver failed (7/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.4809e-03
# Iteration 1000: Loss = 4.8152e-04
#
#
# Solver failed (8/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.5342e-03
# Iteration 1000: Loss = 3.2156e-04
#
#
# Solver failed (9/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.8793e-03
# Iteration 1000: Loss = 3.8969e-04
#
#
# Solver failed (10/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7481e-03
# Iteration 1000: Loss = 3.4749e-04
#
#
# Solver failed (11/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.1477e-03
# Iteration 1000: Loss = 2.6973e-04
#
#
# Solver failed (12/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.5975e-03
# Iteration 1000: Loss = 4.2981e-04
#
#
# Solver failed (13/19): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.4000e-03
# Iteration 1000: Loss = 1.7479e-04
#
#
# Solver failed (14/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.8038e-03
# Iteration 1000: Loss = 3.6999e-04
#
#
# Solver failed (15/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1074e-03
# Iteration 1000: Loss = 4.3550e-04
#
#
# Solver failed (16/16): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2473e-03
# Iteration 1000: Loss = 2.9245e-04
#
#
# Maximum retries reached. Exiting.
# Generated 13323 data from 16 BVP solutions in 365.4 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 1.0682e-04, Loss_V_x = 7.3580e-03, Loss_HJB = 1.1975e-03,  Loss_total = 8.6623e-03
# Iteration 1000: Loss_V = 6.4387e-05, Loss_V_x = 1.8142e-03, Loss_HJB = 1.0383e-03,  Loss_total = 2.9169e-03
# Iteration 2000: Loss_V = 5.2132e-05, Loss_V_x = 1.5151e-03, Loss_HJB = 6.8974e-04,  Loss_total = 2.2570e-03
# Iteration 3000: Loss_V = 6.2556e-05, Loss_V_x = 1.3017e-03, Loss_HJB = 5.5702e-04,  Loss_total = 1.9213e-03
# Iteration 4000: Loss_V = 5.0779e-05, Loss_V_x = 1.1584e-03, Loss_HJB = 4.8662e-04,  Loss_total = 1.6958e-03
# Iteration 5000: Loss_V = 4.2998e-05, Loss_V_x = 1.0664e-03, Loss_HJB = 5.6109e-04,  Loss_total = 1.6705e-03
#
#
# Generating data...
# Solver failed (1/17): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.9225e-03
# Iteration 1000: Loss = 1.9997e-04
#
#
# Solver failed (2/16): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.4032e-03
# Iteration 1000: Loss = 3.3499e-04
#
#
# Solver failed (3/16): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2447e-03
# Iteration 1000: Loss = 2.2802e-04
#
#
# Solver failed (4/6): The maximum number of mesh nodes is exceeded.
# Solver failed (5/6): The maximum number of mesh nodes is exceeded.
# Solver failed (6/6): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 10385 data from 26 BVP solutions in 126.2 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 3.6150e-05, Loss_V_x = 4.9849e-03, Loss_HJB = 1.3042e-03,  Loss_total = 6.3252e-03
# Iteration 1000: Loss_V = 3.8662e-05, Loss_V_x = 8.1722e-04, Loss_HJB = 4.0670e-04,  Loss_total = 1.2626e-03
# Iteration 2000: Loss_V = 4.3403e-05, Loss_V_x = 7.7167e-04, Loss_HJB = 4.1956e-04,  Loss_total = 1.2346e-03
# Iteration 3000: Loss_V = 5.4138e-05, Loss_V_x = 5.8451e-04, Loss_HJB = 4.5376e-04,  Loss_total = 1.0924e-03
# Iteration 4000: Loss_V = 5.5959e-05, Loss_V_x = 5.8633e-04, Loss_HJB = 5.3784e-04,  Loss_total = 1.1801e-03
# Iteration 5000: Loss_V = 5.4271e-05, Loss_V_x = 5.3937e-04, Loss_HJB = 4.8352e-04,  Loss_total = 1.0772e-03
#
#
# Generated 2688 data from 128 IVP solutions in 41.2 sec
#
# Iteration 0:  Loss_G = 9.9773e-02,  Loss_ODE = 2.3665e-01,  Loss_total = 1.0214e-01
# Iteration 1000:  Loss_G = 3.2402e-05,  Loss_ODE = 4.8769e-03,  Loss_total = 8.1171e-05
# Iteration 2000:  Loss_G = 1.6103e-05,  Loss_ODE = 2.2241e-03,  Loss_total = 3.8344e-05
# Iteration 3000:  Loss_G = 1.1230e-05,  Loss_ODE = 1.3249e-03,  Loss_total = 2.4480e-05
# Iteration 4000:  Loss_G = 8.8980e-06,  Loss_ODE = 1.2079e-03,  Loss_total = 2.0977e-05
# Iteration 5000:  Loss_G = 8.6621e-06,  Loss_ODE = 6.4929e-04,  Loss_total = 1.5155e-05
#
#
# Computed J: 2.016637
# Training V2 solution by HJB
# Iteration 0: Loss = 1.7100e-01
# Iteration 1000: Loss = 1.7375e-03
# Iteration 2000: Loss = 1.1007e-03
# Iteration 3000: Loss = 1.1548e-03
# Iteration 4000: Loss = 8.4954e-04
# Iteration 5000: Loss = 6.8434e-04
#
#
# Generating data...
# Generated 4843 data from 32 BVP solutions in 25.2 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 5.9439e-05, Loss_V_x = 1.3297e-03, Loss_HJB = 3.1229e-03,  Loss_total = 4.5120e-03
# Iteration 1000: Loss_V = 3.5322e-06, Loss_V_x = 1.4786e-04, Loss_HJB = 1.2560e-03,  Loss_total = 1.4074e-03
# Iteration 2000: Loss_V = 5.3050e-06, Loss_V_x = 1.3041e-04, Loss_HJB = 7.3407e-04,  Loss_total = 8.6979e-04
# Iteration 3000: Loss_V = 6.0915e-06, Loss_V_x = 9.8395e-05, Loss_HJB = 8.2390e-04,  Loss_total = 9.2839e-04
# Iteration 4000: Loss_V = 6.3558e-07, Loss_V_x = 8.8677e-05, Loss_HJB = 5.8127e-04,  Loss_total = 6.7058e-04
# Iteration 5000: Loss_V = 7.3445e-07, Loss_V_x = 7.8721e-05, Loss_HJB = 5.0740e-04,  Loss_total = 5.8685e-04
#
#
# Generated 2688 data from 128 IVP solutions in 35.9 sec
#
# Iteration 0:  Loss_G = 2.8840e-02,  Loss_ODE = 1.9323e+00,  Loss_total = 4.8163e-02
# Iteration 1000:  Loss_G = 3.7687e-05,  Loss_ODE = 1.9525e-03,  Loss_total = 5.7212e-05
# Iteration 2000:  Loss_G = 1.6468e-05,  Loss_ODE = 8.3156e-04,  Loss_total = 2.4784e-05
# Iteration 3000:  Loss_G = 3.4280e-06,  Loss_ODE = 3.7553e-04,  Loss_total = 7.1833e-06
# Iteration 4000:  Loss_G = 4.6974e-05,  Loss_ODE = 1.9597e-03,  Loss_total = 6.6571e-05
# Iteration 5000:  Loss_G = 2.7329e-06,  Loss_ODE = 2.7713e-04,  Loss_total = 5.5041e-06
#
#
# Computed V0: 1.409350
# Exploitability: 0.607288
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 1.2906e+01
# L2 norm    : 3.0384e+00
# Linf norm  : 8.7138e-01
# ==============================================
#
# Step Time: 961.4 sec
#
#
# --- Step 3 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 1.0355e-01
# Iteration 1000: Loss = 6.7856e-04
# Iteration 2000: Loss = 3.4492e-04
# Iteration 3000: Loss = 3.8032e-04
# Iteration 4000: Loss = 2.6045e-04
# Iteration 5000: Loss = 2.0706e-04
#
#
# Generating data...
# Solver failed (1/32): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.0538e-03
# Iteration 1000: Loss = 5.4369e-04
#
#
# Solver failed (2/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.9844e-03
# Iteration 1000: Loss = 2.9136e-04
#
#
# Solver failed (3/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.3176e-03
# Iteration 1000: Loss = 2.7025e-04
#
#
# Solver failed (4/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.5740e-03
# Iteration 1000: Loss = 3.0262e-04
#
#
# Solver failed (5/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.4754e-03
# Iteration 1000: Loss = 2.8618e-04
#
#
# Solver failed (6/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.3216e-03
# Iteration 1000: Loss = 4.0335e-04
#
#
# Solver failed (7/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1680e-03
# Iteration 1000: Loss = 3.1569e-04
#
#
# Solver failed (8/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.9521e-03
# Iteration 1000: Loss = 1.6516e-04
#
#
# Solver failed (9/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.0051e-03
# Iteration 1000: Loss = 3.5172e-04
#
#
# Solver failed (10/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.9375e-04
# Iteration 1000: Loss = 1.3160e-04
#
#
# Solver failed (11/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.3519e-03
# Iteration 1000: Loss = 1.6630e-04
#
#
# Solver failed (12/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2376e-03
# Iteration 1000: Loss = 2.6006e-04
#
#
# Solver failed (13/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.4132e-04
# Iteration 1000: Loss = 2.6271e-04
#
#
# Solver failed (14/17): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.1445e-04
# Iteration 1000: Loss = 2.1111e-04
#
#
# Solver failed (15/17): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.9057e-04
# Iteration 1000: Loss = 2.2849e-04
#
#
# Solver failed (16/8): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 16013 data from 24 BVP solutions in 480.5 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 4.8622e-05, Loss_V_x = 3.1554e-03, Loss_HJB = 1.2875e-03,  Loss_total = 4.4916e-03
# Iteration 1000: Loss_V = 2.7707e-05, Loss_V_x = 9.7694e-04, Loss_HJB = 6.7990e-04,  Loss_total = 1.6845e-03
# Iteration 2000: Loss_V = 4.5535e-05, Loss_V_x = 7.3922e-04, Loss_HJB = 4.1025e-04,  Loss_total = 1.1950e-03
# Iteration 3000: Loss_V = 5.5426e-05, Loss_V_x = 6.9781e-04, Loss_HJB = 3.0345e-04,  Loss_total = 1.0567e-03
# Iteration 4000: Loss_V = 4.3053e-05, Loss_V_x = 6.2166e-04, Loss_HJB = 2.6039e-04,  Loss_total = 9.2510e-04
# Iteration 5000: Loss_V = 2.9644e-05, Loss_V_x = 6.4762e-04, Loss_HJB = 2.7629e-04,  Loss_total = 9.5356e-04
#
#
# Generated 2688 data from 128 IVP solutions in 41.7 sec
#
# Iteration 0:  Loss_G = 1.5401e-01,  Loss_ODE = 2.2795e-01,  Loss_total = 1.5629e-01
# Iteration 1000:  Loss_G = 5.2641e-05,  Loss_ODE = 5.3295e-03,  Loss_total = 1.0594e-04
# Iteration 2000:  Loss_G = 2.3254e-05,  Loss_ODE = 2.5332e-03,  Loss_total = 4.8586e-05
# Iteration 3000:  Loss_G = 1.3927e-05,  Loss_ODE = 1.6220e-03,  Loss_total = 3.0147e-05
# Iteration 4000:  Loss_G = 8.3732e-06,  Loss_ODE = 6.4922e-04,  Loss_total = 1.4865e-05
# Iteration 5000:  Loss_G = 8.0794e-06,  Loss_ODE = 9.8106e-04,  Loss_total = 1.7890e-05
#
#
# Computed J: 1.955053
# Training V2 solution by HJB
# Iteration 0: Loss = 9.2734e-02
# Iteration 1000: Loss = 7.8319e-04
# Iteration 2000: Loss = 4.9009e-04
# Iteration 3000: Loss = 3.3050e-04
# Iteration 4000: Loss = 2.9605e-04
# Iteration 5000: Loss = 3.3077e-04
#
#
# Generating data...
# Generated 3706 data from 32 BVP solutions in 23.4 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 9.5268e-05, Loss_V_x = 1.3617e-03, Loss_HJB = 1.8409e-03,  Loss_total = 3.2978e-03
# Iteration 1000: Loss_V = 3.7562e-06, Loss_V_x = 4.6003e-04, Loss_HJB = 3.7321e-04,  Loss_total = 8.3699e-04
# Iteration 2000: Loss_V = 3.5686e-06, Loss_V_x = 3.5318e-04, Loss_HJB = 4.6880e-04,  Loss_total = 8.2555e-04
# Iteration 3000: Loss_V = 4.1311e-06, Loss_V_x = 3.5478e-04, Loss_HJB = 4.3027e-04,  Loss_total = 7.8918e-04
# Iteration 4000: Loss_V = 1.4794e-06, Loss_V_x = 3.1863e-04, Loss_HJB = 3.4879e-04,  Loss_total = 6.6889e-04
# Iteration 5000: Loss_V = 1.6644e-06, Loss_V_x = 2.9846e-04, Loss_HJB = 3.0348e-04,  Loss_total = 6.0360e-04
#
#
# Generated 2688 data from 128 IVP solutions in 37.9 sec
#
# Iteration 0:  Loss_G = 3.3016e-01,  Loss_ODE = 3.5960e+00,  Loss_total = 3.6612e-01
# Iteration 1000:  Loss_G = 2.8838e-05,  Loss_ODE = 3.3724e-03,  Loss_total = 6.2562e-05
# Iteration 2000:  Loss_G = 1.3186e-05,  Loss_ODE = 1.5960e-03,  Loss_total = 2.9146e-05
# Iteration 3000:  Loss_G = 1.2771e-05,  Loss_ODE = 1.0773e-03,  Loss_total = 2.3544e-05
# Iteration 4000:  Loss_G = 5.1919e-06,  Loss_ODE = 6.1684e-04,  Loss_total = 1.1360e-05
# Iteration 5000:  Loss_G = 1.2136e-05,  Loss_ODE = 6.3058e-04,  Loss_total = 1.8442e-05
#
#
# Computed V0: 1.441623
# Exploitability: 0.513430
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 1.3409e+01
# L2 norm    : 3.1552e+00
# Linf norm  : 8.9811e-01
# ==============================================
#
# Step Time: 918.6 sec
#
#
# --- Step 4 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 5.8618e-02
# Iteration 1000: Loss = 5.5532e-04
# Iteration 2000: Loss = 2.8948e-04
# Iteration 3000: Loss = 1.1661e-04
# Iteration 4000: Loss = 1.2585e-04
# Iteration 5000: Loss = 9.1443e-05
#
#
# Generating data...
# Solver failed (1/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.0617e-03
# Iteration 1000: Loss = 2.4171e-04
#
#
# Solver failed (2/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.0130e-04
# Iteration 1000: Loss = 1.0937e-04
#
#
# Solver failed (3/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.0188e-03
# Iteration 1000: Loss = 1.8863e-04
#
#
# Solver failed (4/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2547e-03
# Iteration 1000: Loss = 1.6648e-04
#
#
# Solver failed (5/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.4736e-04
# Iteration 1000: Loss = 2.2583e-04
#
#
# Solver failed (6/17): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.2946e-04
# Iteration 1000: Loss = 1.8019e-04
#
#
# Solver failed (7/17): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.5728e-03
# Iteration 1000: Loss = 1.3615e-04
#
#
# Solver failed (8/16): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 7.7350e-04
# Iteration 1000: Loss = 2.4605e-04
#
#
# Solver failed (9/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.5980e-03
# Iteration 1000: Loss = 1.9445e-04
#
#
# Solver failed (10/11): The maximum number of mesh nodes is exceeded.
# Solver failed (11/11): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 13303 data from 21 BVP solutions in 412.1 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 2.4640e-05, Loss_V_x = 3.3173e-03, Loss_HJB = 8.4248e-04,  Loss_total = 4.1845e-03
# Iteration 1000: Loss_V = 1.2362e-05, Loss_V_x = 1.0822e-03, Loss_HJB = 2.2410e-04,  Loss_total = 1.3187e-03
# Iteration 2000: Loss_V = 1.2731e-05, Loss_V_x = 9.5157e-04, Loss_HJB = 2.3921e-04,  Loss_total = 1.2035e-03
# Iteration 3000: Loss_V = 1.4625e-05, Loss_V_x = 9.2467e-04, Loss_HJB = 3.1954e-04,  Loss_total = 1.2588e-03
# Iteration 4000: Loss_V = 1.4138e-05, Loss_V_x = 8.4703e-04, Loss_HJB = 2.6187e-04,  Loss_total = 1.1230e-03
# Iteration 5000: Loss_V = 1.3700e-05, Loss_V_x = 7.6660e-04, Loss_HJB = 2.6417e-04,  Loss_total = 1.0445e-03
#
#
# Generated 2688 data from 128 IVP solutions in 41.9 sec
#
# Iteration 0:  Loss_G = 8.0244e-02,  Loss_ODE = 1.5784e-01,  Loss_total = 8.1822e-02
# Iteration 1000:  Loss_G = 2.9358e-05,  Loss_ODE = 3.9791e-03,  Loss_total = 6.9149e-05
# Iteration 2000:  Loss_G = 1.5469e-05,  Loss_ODE = 1.2116e-03,  Loss_total = 2.7584e-05
# Iteration 3000:  Loss_G = 1.2129e-05,  Loss_ODE = 1.0846e-03,  Loss_total = 2.2976e-05
# Iteration 4000:  Loss_G = 2.7499e-05,  Loss_ODE = 1.4862e-03,  Loss_total = 4.2361e-05
# Iteration 5000:  Loss_G = 7.0587e-06,  Loss_ODE = 7.9467e-04,  Loss_total = 1.5005e-05
#
#
# Computed J: 1.811556
# Training V2 solution by HJB
# Iteration 0: Loss = 3.7492e-02
# Iteration 1000: Loss = 6.0196e-04
# Iteration 2000: Loss = 3.0561e-04
# Iteration 3000: Loss = 2.7583e-04
# Iteration 4000: Loss = 2.1155e-04
# Iteration 5000: Loss = 2.1975e-04
#
#
# Generating data...
# Solver failed (1/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.5185e-03
# Iteration 1000: Loss = 2.7284e-04
#
#
# Solver failed (2/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.9563e-03
# Iteration 1000: Loss = 3.8583e-04
#
#
# Solver failed (3/22): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.2955e-03
# Iteration 1000: Loss = 3.1568e-04
#
#
# Solver failed (4/21): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.3724e-03
# Iteration 1000: Loss = 2.5317e-04
#
#
# Solver failed (5/21): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.9295e-03
# Iteration 1000: Loss = 4.2687e-04
#
#
# Solver failed (6/21): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.1655e-03
# Iteration 1000: Loss = 2.3000e-04
#
#
# Solver failed (7/21): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6856e-03
# Iteration 1000: Loss = 1.4122e-04
#
#
# Solver failed (8/21): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6007e-03
# Iteration 1000: Loss = 2.6486e-04
#
#
# Solver failed (9/21): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.9508e-03
# Iteration 1000: Loss = 2.8442e-04
#
#
# Solver failed (10/21): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.0434e-03
# Iteration 1000: Loss = 1.7704e-04
#
#
# Solver failed (11/6): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 8347 data from 26 BVP solutions in 167.6 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 5.1212e-06, Loss_V_x = 9.9692e-04, Loss_HJB = 1.3782e-03,  Loss_total = 2.3802e-03
# Iteration 1000: Loss_V = 5.0721e-06, Loss_V_x = 1.9878e-04, Loss_HJB = 2.8337e-04,  Loss_total = 4.8722e-04
# Iteration 2000: Loss_V = 2.4042e-06, Loss_V_x = 1.6327e-04, Loss_HJB = 2.0028e-04,  Loss_total = 3.6595e-04
# Iteration 3000: Loss_V = 7.6557e-07, Loss_V_x = 1.5011e-04, Loss_HJB = 1.8662e-04,  Loss_total = 3.3749e-04
# Iteration 4000: Loss_V = 1.6994e-06, Loss_V_x = 1.5697e-04, Loss_HJB = 3.2118e-04,  Loss_total = 4.7986e-04
# Iteration 5000: Loss_V = 1.1711e-06, Loss_V_x = 1.4899e-04, Loss_HJB = 2.5155e-04,  Loss_total = 4.0171e-04
#
#
# Generated 2688 data from 128 IVP solutions in 35.7 sec
#
# Iteration 0:  Loss_G = 3.2503e-02,  Loss_ODE = 1.9540e+00,  Loss_total = 5.2043e-02
# Iteration 1000:  Loss_G = 2.3334e-05,  Loss_ODE = 2.7416e-03,  Loss_total = 5.0751e-05
# Iteration 2000:  Loss_G = 1.2461e-05,  Loss_ODE = 8.8064e-04,  Loss_total = 2.1267e-05
# Iteration 3000:  Loss_G = 2.3515e-05,  Loss_ODE = 1.1113e-03,  Loss_total = 3.4628e-05
# Iteration 4000:  Loss_G = 8.4552e-06,  Loss_ODE = 7.4928e-04,  Loss_total = 1.5948e-05
# Iteration 5000:  Loss_G = 3.5514e-06,  Loss_ODE = 3.4160e-04,  Loss_total = 6.9675e-06
#
#
# Computed V0: 1.605512
# Exploitability: 0.206043
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 9.4616e+00
# L2 norm    : 2.2325e+00
# Linf norm  : 6.4383e-01
# ==============================================
#
# Step Time: 1036.2 sec
#
#
# --- Step 5 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 2.8461e-02
# Iteration 1000: Loss = 5.9336e-04
# Iteration 2000: Loss = 1.7775e-04
# Iteration 3000: Loss = 2.2325e-04
# Iteration 4000: Loss = 1.6145e-04
# Iteration 5000: Loss = 1.2256e-04
#
#
# Generating data...
# Solver failed (1/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.0754e-03
# Iteration 1000: Loss = 2.1802e-04
#
#
# Solver failed (2/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.2959e-03
# Iteration 1000: Loss = 1.9133e-04
#
#
# Solver failed (3/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1904e-03
# Iteration 1000: Loss = 1.1635e-04
#
#
# Solver failed (4/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2739e-03
# Iteration 1000: Loss = 2.0888e-04
#
#
# Solver failed (5/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.2503e-04
# Iteration 1000: Loss = 9.1570e-05
#
#
# Solver failed (6/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6147e-03
# Iteration 1000: Loss = 2.3399e-04
#
#
# Solver failed (7/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.0765e-04
# Iteration 1000: Loss = 2.2538e-04
#
#
# Solver failed (8/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1543e-03
# Iteration 1000: Loss = 1.0111e-04
#
#
# Solver failed (9/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7186e-03
# Iteration 1000: Loss = 2.0174e-04
#
#
# Solver failed (10/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1676e-03
# Iteration 1000: Loss = 2.8173e-04
#
#
# Solver failed (11/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.5969e-04
# Iteration 1000: Loss = 3.4754e-04
#
#
# Solver failed (12/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1458e-03
# Iteration 1000: Loss = 2.0126e-04
#
#
# Solver failed (13/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.2543e-04
# Iteration 1000: Loss = 2.3382e-04
#
#
# Solver failed (14/26): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1198e-03
# Iteration 1000: Loss = 1.0392e-04
#
#
# Solver failed (15/26): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.8993e-03
# Iteration 1000: Loss = 9.9885e-05
#
#
# Solver failed (16/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.1932e-03
# Iteration 1000: Loss = 8.4207e-05
#
#
# Solver failed (17/22): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 7.4645e-04
# Iteration 1000: Loss = 1.3907e-04
#
#
# Solver failed (18/19): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6132e-03
# Iteration 1000: Loss = 1.2784e-04
#
#
# Solver failed (19/17): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7140e-03
# Iteration 1000: Loss = 1.9033e-04
#
#
# Maximum retries reached. Exiting.
# Generated 10883 data from 15 BVP solutions in 856.0 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 2.7085e-05, Loss_V_x = 3.6258e-03, Loss_HJB = 1.6833e-03,  Loss_total = 5.3363e-03
# Iteration 1000: Loss_V = 1.3942e-05, Loss_V_x = 7.6333e-04, Loss_HJB = 3.4796e-04,  Loss_total = 1.1252e-03
# Iteration 2000: Loss_V = 1.0629e-05, Loss_V_x = 6.7606e-04, Loss_HJB = 3.2306e-04,  Loss_total = 1.0098e-03
# Iteration 3000: Loss_V = 1.1746e-05, Loss_V_x = 6.7519e-04, Loss_HJB = 3.2595e-04,  Loss_total = 1.0129e-03
# Iteration 4000: Loss_V = 1.0539e-05, Loss_V_x = 6.2476e-04, Loss_HJB = 2.8483e-04,  Loss_total = 9.2013e-04
# Iteration 5000: Loss_V = 1.0644e-05, Loss_V_x = 5.5167e-04, Loss_HJB = 2.1478e-04,  Loss_total = 7.7709e-04
#
#
# Generating data...
# Generated 7072 data from 32 BVP solutions in 68.5 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 1.7653e-05, Loss_V_x = 1.3042e-03, Loss_HJB = 1.1585e-03,  Loss_total = 2.4804e-03
# Iteration 1000: Loss_V = 1.9138e-05, Loss_V_x = 9.4863e-04, Loss_HJB = 2.9198e-04,  Loss_total = 1.2598e-03
# Iteration 2000: Loss_V = 2.1147e-05, Loss_V_x = 9.1346e-04, Loss_HJB = 2.7280e-04,  Loss_total = 1.2074e-03
# Iteration 3000: Loss_V = 1.9193e-05, Loss_V_x = 8.7322e-04, Loss_HJB = 2.2361e-04,  Loss_total = 1.1160e-03
# Iteration 4000: Loss_V = 1.8951e-05, Loss_V_x = 8.4975e-04, Loss_HJB = 2.3795e-04,  Loss_total = 1.1066e-03
# Iteration 5000: Loss_V = 2.1084e-05, Loss_V_x = 8.2690e-04, Loss_HJB = 2.3780e-04,  Loss_total = 1.0858e-03
#
#
# Generated 2688 data from 128 IVP solutions in 44.4 sec
#
# Iteration 0:  Loss_G = 3.5653e-02,  Loss_ODE = 5.5874e-02,  Loss_total = 3.6211e-02
# Iteration 1000:  Loss_G = 2.0244e-05,  Loss_ODE = 3.2484e-03,  Loss_total = 5.2728e-05
# Iteration 2000:  Loss_G = 1.7817e-05,  Loss_ODE = 1.8263e-03,  Loss_total = 3.6080e-05
# Iteration 3000:  Loss_G = 7.6387e-06,  Loss_ODE = 5.5189e-04,  Loss_total = 1.3158e-05
# Iteration 4000:  Loss_G = 9.0779e-06,  Loss_ODE = 4.5844e-04,  Loss_total = 1.3662e-05
# Iteration 5000:  Loss_G = 6.2555e-06,  Loss_ODE = 5.2732e-04,  Loss_total = 1.1529e-05
#
#
# Computed J: 1.764033
# Training V2 solution by HJB
# Iteration 0: Loss = 9.3445e-03
# Iteration 1000: Loss = 5.7749e-04
# Iteration 2000: Loss = 1.4739e-04
# Iteration 3000: Loss = 1.3620e-04
# Iteration 4000: Loss = 2.9366e-04
# Iteration 5000: Loss = 2.0242e-04
#
#
# Generating data...
# Solver failed (1/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6452e-03
# Iteration 1000: Loss = 1.1410e-04
#
#
# Solver failed (2/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1485e-03
# Iteration 1000: Loss = 1.1319e-04
#
#
# Solver failed (3/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.5805e-03
# Iteration 1000: Loss = 1.7154e-04
#
#
# Solver failed (4/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.6653e-03
# Iteration 1000: Loss = 1.5316e-04
#
#
# Solver failed (5/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2453e-03
# Iteration 1000: Loss = 1.6367e-04
#
#
# Solver failed (6/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2021e-03
# Iteration 1000: Loss = 1.7018e-04
#
#
# Solver failed (7/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.8872e-03
# Iteration 1000: Loss = 2.4345e-04
#
#
# Solver failed (8/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.1641e-03
# Iteration 1000: Loss = 2.7225e-04
#
#
# Solver failed (9/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1700e-03
# Iteration 1000: Loss = 1.7563e-04
#
#
# Solver failed (10/10): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 14432 data from 22 BVP solutions in 145.4 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 5.1212e-05, Loss_V_x = 2.3798e-03, Loss_HJB = 4.5425e-03,  Loss_total = 6.9736e-03
# Iteration 1000: Loss_V = 6.2330e-06, Loss_V_x = 3.1579e-04, Loss_HJB = 2.1903e-04,  Loss_total = 5.4105e-04
# Iteration 2000: Loss_V = 3.8143e-06, Loss_V_x = 2.9128e-04, Loss_HJB = 3.3329e-04,  Loss_total = 6.2838e-04
# Iteration 3000: Loss_V = 3.9599e-06, Loss_V_x = 2.3955e-04, Loss_HJB = 2.7712e-04,  Loss_total = 5.2063e-04
# Iteration 4000: Loss_V = 6.5964e-06, Loss_V_x = 2.0337e-04, Loss_HJB = 1.7063e-04,  Loss_total = 3.8060e-04
# Iteration 5000: Loss_V = 3.9691e-06, Loss_V_x = 1.8557e-04, Loss_HJB = 1.6546e-04,  Loss_total = 3.5500e-04
#
#
# Generated 2688 data from 128 IVP solutions in 42.1 sec
#
# Iteration 0:  Loss_G = 2.4479e-01,  Loss_ODE = 2.2728e+00,  Loss_total = 2.6752e-01
# Iteration 1000:  Loss_G = 1.4309e-04,  Loss_ODE = 1.0671e-02,  Loss_total = 2.4980e-04
# Iteration 2000:  Loss_G = 4.8823e-05,  Loss_ODE = 5.3956e-03,  Loss_total = 1.0278e-04
# Iteration 3000:  Loss_G = 2.8093e-05,  Loss_ODE = 3.5309e-03,  Loss_total = 6.3402e-05
# Iteration 4000:  Loss_G = 3.5620e-05,  Loss_ODE = 3.8538e-03,  Loss_total = 7.4158e-05
# Iteration 5000:  Loss_G = 2.4506e-05,  Loss_ODE = 2.4128e-03,  Loss_total = 4.8634e-05
#
#
# Computed V0: 1.693988
# Exploitability: 0.070045
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 8.7234e+00
# L2 norm    : 2.0706e+00
# Linf norm  : 6.0712e-01
# ==============================================
#
# Step Time: 1723.1 sec
#
#
# --- Step 6 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 8.0269e-03
# Iteration 1000: Loss = 2.2194e-04
# Iteration 2000: Loss = 1.8735e-04
# Iteration 3000: Loss = 8.7729e-05
# Iteration 4000: Loss = 1.0741e-04
# Iteration 5000: Loss = 7.7665e-05
#
#
# Generating data...
# Solver failed (1/32): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2341e-03
# Iteration 1000: Loss = 1.1165e-04
#
#
# Solver failed (2/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.4078e-04
# Iteration 1000: Loss = 9.5421e-05
#
#
# Solver failed (3/26): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.9587e-03
# Iteration 1000: Loss = 9.0202e-05
#
#
# Solver failed (4/22): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.9467e-04
# Iteration 1000: Loss = 8.4055e-05
#
#
# Solver failed (5/22): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1684e-03
# Iteration 1000: Loss = 1.7279e-04
#
#
# Solver failed (6/22): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.9561e-04
# Iteration 1000: Loss = 7.2398e-05
#
#
# Solver failed (7/19): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 7.0064e-04
# Iteration 1000: Loss = 1.3512e-04
#
#
# Solver failed (8/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.0654e-03
# Iteration 1000: Loss = 1.0863e-04
#
#
# Solver failed (9/11): The maximum number of mesh nodes is exceeded.
# Solver failed (10/11): The maximum number of mesh nodes is exceeded.
# Solver failed (11/11): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 28320 data from 21 BVP solutions in 633.3 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 5.4232e-05, Loss_V_x = 2.6920e-03, Loss_HJB = 9.2468e-04,  Loss_total = 3.6709e-03
# Iteration 1000: Loss_V = 3.6159e-05, Loss_V_x = 5.7745e-04, Loss_HJB = 2.4408e-04,  Loss_total = 8.5768e-04
# Iteration 2000: Loss_V = 3.1298e-05, Loss_V_x = 5.1102e-04, Loss_HJB = 2.6778e-04,  Loss_total = 8.1010e-04
# Iteration 3000: Loss_V = 2.2980e-05, Loss_V_x = 4.9777e-04, Loss_HJB = 1.6656e-04,  Loss_total = 6.8731e-04
# Iteration 4000: Loss_V = 2.7359e-05, Loss_V_x = 5.2563e-04, Loss_HJB = 3.6376e-04,  Loss_total = 9.1674e-04
# Iteration 5000: Loss_V = 2.6955e-05, Loss_V_x = 5.0609e-04, Loss_HJB = 2.8096e-04,  Loss_total = 8.1400e-04
#
#
# Generated 2688 data from 128 IVP solutions in 44.5 sec
#
# Iteration 0:  Loss_G = 9.6286e-03,  Loss_ODE = 3.4818e-02,  Loss_total = 9.9768e-03
# Iteration 1000:  Loss_G = 1.5603e-05,  Loss_ODE = 1.3049e-03,  Loss_total = 2.8652e-05
# Iteration 2000:  Loss_G = 9.2815e-06,  Loss_ODE = 5.4009e-04,  Loss_total = 1.4682e-05
# Iteration 3000:  Loss_G = 4.6082e-06,  Loss_ODE = 2.1920e-04,  Loss_total = 6.8002e-06
# Iteration 4000:  Loss_G = 4.0559e-06,  Loss_ODE = 4.3531e-04,  Loss_total = 8.4089e-06
# Iteration 5000:  Loss_G = 4.7950e-06,  Loss_ODE = 3.5444e-04,  Loss_total = 8.3394e-06
#
#
# Computed J: 1.753975
# Training V2 solution by HJB
# Iteration 0: Loss = 1.0455e-02
# Iteration 1000: Loss = 2.1233e-04
# Iteration 2000: Loss = 1.2550e-04
# Iteration 3000: Loss = 1.0372e-04
# Iteration 4000: Loss = 6.8156e-05
# Iteration 5000: Loss = 9.9042e-05
#
#
# Generating data...
# Solver failed (1/20): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.4353e-03
# Iteration 1000: Loss = 1.1700e-04
#
#
# Solver failed (2/7): The maximum number of mesh nodes is exceeded.
# Solver failed (3/7): The maximum number of mesh nodes is exceeded.
# Solver failed (4/7): The maximum number of mesh nodes is exceeded.
# Solver failed (5/7): The maximum number of mesh nodes is exceeded.
# Solver failed (6/7): The maximum number of mesh nodes is exceeded.
# Solver failed (7/7): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 17406 data from 25 BVP solutions in 75.6 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 3.9288e-05, Loss_V_x = 5.2766e-03, Loss_HJB = 2.0192e-03,  Loss_total = 7.3351e-03
# Iteration 1000: Loss_V = 2.3465e-05, Loss_V_x = 5.1798e-04, Loss_HJB = 2.5191e-04,  Loss_total = 7.9335e-04
# Iteration 2000: Loss_V = 2.5139e-05, Loss_V_x = 4.3310e-04, Loss_HJB = 2.6482e-04,  Loss_total = 7.2306e-04
# Iteration 3000: Loss_V = 2.6364e-05, Loss_V_x = 4.2321e-04, Loss_HJB = 2.9965e-04,  Loss_total = 7.4923e-04
# Iteration 4000: Loss_V = 2.1857e-05, Loss_V_x = 3.8613e-04, Loss_HJB = 2.3616e-04,  Loss_total = 6.4415e-04
# Iteration 5000: Loss_V = 3.3361e-05, Loss_V_x = 3.5220e-04, Loss_HJB = 2.5500e-04,  Loss_total = 6.4055e-04
#
#
# Generated 2688 data from 128 IVP solutions in 42.2 sec
#
# Iteration 0:  Loss_G = 9.4206e-02,  Loss_ODE = 1.9889e+00,  Loss_total = 1.1409e-01
# Iteration 1000:  Loss_G = 6.2082e-05,  Loss_ODE = 8.5807e-03,  Loss_total = 1.4789e-04
# Iteration 2000:  Loss_G = 2.0140e-05,  Loss_ODE = 2.7354e-03,  Loss_total = 4.7494e-05
# Iteration 3000:  Loss_G = 1.2826e-05,  Loss_ODE = 1.7340e-03,  Loss_total = 3.0166e-05
# Iteration 4000:  Loss_G = 5.3959e-05,  Loss_ODE = 3.2715e-03,  Loss_total = 8.6674e-05
# Iteration 5000:  Loss_G = 8.2187e-05,  Loss_ODE = 3.7740e-03,  Loss_total = 1.1993e-04
#
#
# Computed V0: 1.705488
# Exploitability: 0.048487
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 4.8524e+00
# L2 norm    : 1.1586e+00
# Linf norm  : 3.4872e-01
# ==============================================
#
# Step Time: 1274.3 sec
#
#
# --- Step 7 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 6.9982e-03
# Iteration 1000: Loss = 1.4061e-04
# Iteration 2000: Loss = 1.3382e-04
# Iteration 3000: Loss = 1.3963e-04
# Iteration 4000: Loss = 1.0081e-04
# Iteration 5000: Loss = 1.0064e-04
#
#
# Generating data...
# Solver failed (1/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.4394e-04
# Iteration 1000: Loss = 8.7879e-05
#
#
# Solver failed (2/30): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.5813e-04
# Iteration 1000: Loss = 1.0332e-04
#
#
# Solver failed (3/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.2286e-04
# Iteration 1000: Loss = 1.2001e-04
#
#
# Solver failed (4/26): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6840e-03
# Iteration 1000: Loss = 1.5313e-04
#
#
# Solver failed (5/16): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2093e-03
# Iteration 1000: Loss = 8.8020e-05
#
#
# Solver failed (6/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.8270e-04
# Iteration 1000: Loss = 6.7055e-05
#
#
# Solver failed (7/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.1832e-03
# Iteration 1000: Loss = 2.8140e-04
#
#
# Solver failed (8/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2357e-03
# Iteration 1000: Loss = 8.0941e-05
#
#
# Solver failed (9/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 7.7438e-04
# Iteration 1000: Loss = 1.9470e-04
#
#
# Solver failed (10/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1517e-03
# Iteration 1000: Loss = 7.8019e-05
#
#
# Solver failed (11/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.0865e-04
# Iteration 1000: Loss = 1.2047e-04
#
#
# Solver failed (12/12): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 6099 data from 20 BVP solutions in 777.2 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 3.6336e-05, Loss_V_x = 1.6613e-03, Loss_HJB = 1.4111e-03,  Loss_total = 3.1087e-03
# Iteration 1000: Loss_V = 1.4864e-05, Loss_V_x = 5.1649e-04, Loss_HJB = 2.1868e-04,  Loss_total = 7.5003e-04
# Iteration 2000: Loss_V = 1.6104e-05, Loss_V_x = 4.6859e-04, Loss_HJB = 2.0403e-04,  Loss_total = 6.8873e-04
# Iteration 3000: Loss_V = 1.2873e-05, Loss_V_x = 4.3442e-04, Loss_HJB = 1.1599e-04,  Loss_total = 5.6328e-04
# Iteration 4000: Loss_V = 1.6512e-05, Loss_V_x = 4.1907e-04, Loss_HJB = 1.7373e-04,  Loss_total = 6.0931e-04
# Iteration 5000: Loss_V = 1.3781e-05, Loss_V_x = 3.9646e-04, Loss_HJB = 1.2337e-04,  Loss_total = 5.3361e-04
#
#
# Generated 2688 data from 128 IVP solutions in 41.8 sec
#
# Iteration 0:  Loss_G = 1.0863e-02,  Loss_ODE = 2.1019e-02,  Loss_total = 1.1073e-02
# Iteration 1000:  Loss_G = 9.4955e-06,  Loss_ODE = 8.6397e-04,  Loss_total = 1.8135e-05
# Iteration 2000:  Loss_G = 6.4525e-06,  Loss_ODE = 6.9579e-04,  Loss_total = 1.3410e-05
# Iteration 3000:  Loss_G = 4.4427e-06,  Loss_ODE = 3.2537e-04,  Loss_total = 7.6964e-06
# Iteration 4000:  Loss_G = 7.9171e-06,  Loss_ODE = 4.1702e-04,  Loss_total = 1.2087e-05
# Iteration 5000:  Loss_G = 3.7543e-06,  Loss_ODE = 2.4348e-04,  Loss_total = 6.1891e-06
#
#
# Computed J: 1.762672
# Training V2 solution by HJB
# Iteration 0: Loss = 7.1602e-03
# Iteration 1000: Loss = 1.7319e-04
# Iteration 2000: Loss = 1.4347e-04
# Iteration 3000: Loss = 1.3359e-04
# Iteration 4000: Loss = 1.1146e-04
# Iteration 5000: Loss = 9.7326e-04
#
#
# Generating data...
# Solver failed (1/28): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7153e-03
# Iteration 1000: Loss = 1.5338e-04
#
#
# Solver failed (2/27): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.5954e-04
# Iteration 1000: Loss = 2.1227e-04
#
#
# Solver failed (3/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1888e-03
# Iteration 1000: Loss = 1.6013e-04
#
#
# Solver failed (4/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.0563e-03
# Iteration 1000: Loss = 1.1906e-04
#
#
# Solver failed (5/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.2325e-03
# Iteration 1000: Loss = 1.2554e-04
#
#
# Solver failed (6/14): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.4527e-03
# Iteration 1000: Loss = 1.1186e-04
#
#
# Solver failed (7/14): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.0179e-03
# Iteration 1000: Loss = 7.0914e-05
#
#
# Solver failed (8/14): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.0377e-03
# Iteration 1000: Loss = 1.1064e-04
#
#
# Solver failed (9/12): The maximum number of mesh nodes is exceeded.
# Solver failed (10/12): The maximum number of mesh nodes is exceeded.
# Solver failed (11/12): The maximum number of mesh nodes is exceeded.
# Solver failed (12/12): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 18736 data from 20 BVP solutions in 160.7 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 1.0095e-04, Loss_V_x = 4.7828e-03, Loss_HJB = 8.3413e-04,  Loss_total = 5.7178e-03
# Iteration 1000: Loss_V = 4.9189e-06, Loss_V_x = 6.8533e-04, Loss_HJB = 2.8153e-04,  Loss_total = 9.7177e-04
# Iteration 2000: Loss_V = 3.3127e-06, Loss_V_x = 6.1648e-04, Loss_HJB = 2.2865e-04,  Loss_total = 8.4845e-04
# Iteration 3000: Loss_V = 3.6266e-06, Loss_V_x = 5.4375e-04, Loss_HJB = 1.7379e-04,  Loss_total = 7.2117e-04
# Iteration 4000: Loss_V = 3.7961e-06, Loss_V_x = 5.1450e-04, Loss_HJB = 2.4706e-04,  Loss_total = 7.6536e-04
# Iteration 5000: Loss_V = 4.6641e-06, Loss_V_x = 4.7836e-04, Loss_HJB = 2.0164e-04,  Loss_total = 6.8466e-04
#
#
# Generated 2688 data from 128 IVP solutions in 41.7 sec
#
# Iteration 0:  Loss_G = 2.4180e-01,  Loss_ODE = 2.1103e+00,  Loss_total = 2.6290e-01
# Iteration 1000:  Loss_G = 9.4513e-05,  Loss_ODE = 1.3632e-02,  Loss_total = 2.3083e-04
# Iteration 2000:  Loss_G = 5.5655e-05,  Loss_ODE = 7.1917e-03,  Loss_total = 1.2757e-04
# Iteration 3000:  Loss_G = 3.9659e-05,  Loss_ODE = 5.4482e-03,  Loss_total = 9.4141e-05
# Iteration 4000:  Loss_G = 2.4750e-05,  Loss_ODE = 6.0557e-03,  Loss_total = 8.5307e-05
# Iteration 5000:  Loss_G = 3.2592e-05,  Loss_ODE = 2.8629e-03,  Loss_total = 6.1221e-05
#
#
# Computed V0: 1.706699
# Exploitability: 0.055973
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 7.8204e+00
# L2 norm    : 1.8552e+00
# Linf norm  : 5.4414e-01
# ==============================================
#
# Step Time: 1533.3 sec
#
#
# --- Step 8 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 5.7885e-03
# Iteration 1000: Loss = 1.2274e-04
# Iteration 2000: Loss = 1.1578e-04
# Iteration 3000: Loss = 7.9731e-05
# Iteration 4000: Loss = 9.7188e-05
# Iteration 5000: Loss = 2.1154e-04
#
#
# Generating data...
# Solver failed (1/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.8119e-03
# Iteration 1000: Loss = 1.3554e-04
#
#
# Solver failed (2/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7034e-03
# Iteration 1000: Loss = 1.1104e-04
#
#
# Solver failed (3/14): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.4116e-04
# Iteration 1000: Loss = 7.3445e-05
#
#
# Solver failed (4/14): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.8351e-04
# Iteration 1000: Loss = 4.6590e-05
#
#
# Solver failed (5/14): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.5047e-03
# Iteration 1000: Loss = 6.7165e-05
#
#
# ...
# Iteration 0: Loss = 8.9556e-04
# Iteration 1000: Loss = 4.4748e-05
#
#
# Solver failed (2/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.9971e-04
# Iteration 1000: Loss = 3.0770e-05
#
#
# Solver failed (3/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.8555e-04
# Iteration 1000: Loss = 7.6288e-05
#
#
# Solver failed (4/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.9730e-04
# Iteration 1000: Loss = 3.5563e-05
#
#
# Solver failed (5/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1382e-03
# Iteration 1000: Loss = 2.4894e-05
#
#
# Solver failed (6/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.4130e-04
# Iteration 1000: Loss = 2.7755e-05
#
#
# Solver failed (7/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7813e-03
# Iteration 1000: Loss = 2.0802e-05
#
#
# Solver failed (8/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.4335e-04
# Iteration 1000: Loss = 2.1147e-05
#
#
# Solver failed (9/24): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.5421e-04
# Iteration 1000: Loss = 2.0380e-05
#
#
# Solver failed (10/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.9734e-04
# Iteration 1000: Loss = 1.7663e-05
#
#
# Solver failed (11/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.0734e-04
# Iteration 1000: Loss = 3.3385e-05
#
#
# Generated 15244 data from 32 BVP solutions in 520.7 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 8.2867e-06, Loss_V_x = 1.3704e-03, Loss_HJB = 5.3135e-04,  Loss_total = 1.9101e-03
# Iteration 1000: Loss_V = 7.4432e-06, Loss_V_x = 3.0252e-04, Loss_HJB = 7.9858e-05,  Loss_total = 3.8983e-04
# Iteration 2000: Loss_V = 6.5254e-06, Loss_V_x = 2.4535e-04, Loss_HJB = 6.7212e-05,  Loss_total = 3.1908e-04
# Iteration 3000: Loss_V = 2.1406e-05, Loss_V_x = 2.3136e-04, Loss_HJB = 1.4563e-04,  Loss_total = 3.9839e-04
# Iteration 4000: Loss_V = 4.7417e-06, Loss_V_x = 1.9946e-04, Loss_HJB = 2.8710e-05,  Loss_total = 2.3291e-04
# Iteration 5000: Loss_V = 5.2845e-06, Loss_V_x = 2.0456e-04, Loss_HJB = 4.1055e-05,  Loss_total = 2.5090e-04
#
#
# Generated 2688 data from 128 IVP solutions in 40.9 sec
#
# Iteration 0:  Loss_G = 4.1327e-02,  Loss_ODE = 1.0755e-01,  Loss_total = 4.2403e-02
# Iteration 1000:  Loss_G = 2.7946e-05,  Loss_ODE = 4.3375e-03,  Loss_total = 7.1322e-05
# Iteration 2000:  Loss_G = 1.5401e-05,  Loss_ODE = 1.5420e-03,  Loss_total = 3.0821e-05
# Iteration 3000:  Loss_G = 8.2430e-06,  Loss_ODE = 7.5513e-04,  Loss_total = 1.5794e-05
# Iteration 4000:  Loss_G = 6.1982e-06,  Loss_ODE = 3.9356e-04,  Loss_total = 1.0134e-05
# Iteration 5000:  Loss_G = 4.1335e-06,  Loss_ODE = 2.5793e-04,  Loss_total = 6.7128e-06
#
#
# Computed J: 1.828499
# Training V2 solution by HJB
# Iteration 0: Loss = 3.4732e-02
# Iteration 1000: Loss = 1.6809e-04
# Iteration 2000: Loss = 1.3814e-04
# Iteration 3000: Loss = 1.2614e-04
# Iteration 4000: Loss = 6.5417e-05
# Iteration 5000: Loss = 1.3733e-04
#
#
# Generating data...
# Solver failed (1/19): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6167e-03
# Iteration 1000: Loss = 1.0325e-04
#
#
# Generated 4016 data from 32 BVP solutions in 39.8 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 2.3214e-05, Loss_V_x = 1.2323e-03, Loss_HJB = 8.9621e-04,  Loss_total = 2.1518e-03
# Iteration 1000: Loss_V = 6.6408e-07, Loss_V_x = 1.5569e-04, Loss_HJB = 1.2941e-04,  Loss_total = 2.8577e-04
# Iteration 2000: Loss_V = 8.2404e-07, Loss_V_x = 1.1294e-04, Loss_HJB = 9.4104e-05,  Loss_total = 2.0787e-04
# Iteration 3000: Loss_V = 1.7059e-06, Loss_V_x = 8.7801e-05, Loss_HJB = 9.8995e-05,  Loss_total = 1.8850e-04
# Iteration 4000: Loss_V = 5.2185e-07, Loss_V_x = 8.9203e-05, Loss_HJB = 6.9625e-05,  Loss_total = 1.5935e-04
# Iteration 5000: Loss_V = 6.1677e-07, Loss_V_x = 8.3320e-05, Loss_HJB = 6.0759e-05,  Loss_total = 1.4470e-04
#
#
# Generated 2688 data from 128 IVP solutions in 41.9 sec
#
# Iteration 0:  Loss_G = 3.1306e-01,  Loss_ODE = 2.9750e+00,  Loss_total = 3.4281e-01
# Iteration 1000:  Loss_G = 2.5509e-05,  Loss_ODE = 5.3428e-03,  Loss_total = 7.8938e-05
# Iteration 2000:  Loss_G = 1.2552e-05,  Loss_ODE = 2.1385e-03,  Loss_total = 3.3936e-05
# Iteration 3000:  Loss_G = 9.2347e-06,  Loss_ODE = 1.3040e-03,  Loss_total = 2.2274e-05
# Iteration 4000:  Loss_G = 7.1869e-06,  Loss_ODE = 8.9129e-04,  Loss_total = 1.6100e-05
# Iteration 5000:  Loss_G = 3.3935e-05,  Loss_ODE = 1.9586e-03,  Loss_total = 5.3521e-05
#
#
# Computed V0: 1.564477
# Exploitability: 0.264022
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 1.1685e+01
# L2 norm    : 2.7552e+00
# Linf norm  : 7.9119e-01
# ==============================================
#
# Step Time: 2032.4 sec
#
#
# --- Step 4 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 2.1664e-02
# Iteration 1000: Loss = 8.4239e-05
# Iteration 2000: Loss = 3.5746e-05
# Iteration 3000: Loss = 5.9782e-05
# Iteration 4000: Loss = 3.3064e-05
# Iteration 5000: Loss = 3.2697e-05
#
#
# Generating data...
# Solver failed (1/25): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.0402e-04
# Iteration 1000: Loss = 2.6834e-05
#
#
# Solver failed (2/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.0697e-04
# Iteration 1000: Loss = 2.5702e-05
#
#
# Solver failed (3/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.2131e-04
# Iteration 1000: Loss = 3.7200e-05
#
#
# Solver failed (4/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.9767e-04
# Iteration 1000: Loss = 2.2704e-05
#
#
# Solver failed (5/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 7.9438e-04
# Iteration 1000: Loss = 2.2949e-05
#
#
# Solver failed (6/22): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.8787e-04
# Iteration 1000: Loss = 1.7540e-05
#
#
# Solver failed (7/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1770e-03
# Iteration 1000: Loss = 1.6217e-05
#
#
# Solver failed (8/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.2990e-04
# Iteration 1000: Loss = 2.1288e-05
#
#
# Solver failed (9/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 5.3728e-04
# Iteration 1000: Loss = 6.7107e-05
#
#
# Solver failed (10/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 7.7852e-04
# Iteration 1000: Loss = 3.2715e-05
#
#
# Solver failed (11/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 8.0172e-04
# Iteration 1000: Loss = 1.9341e-05
#
#
# Solver failed (12/18): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 6.2880e-04
# Iteration 1000: Loss = 4.0168e-05
#
#
# Solver failed (13/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.5705e-03
# Iteration 1000: Loss = 2.2688e-05
#
#
# Solver failed (14/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.3942e-04
# Iteration 1000: Loss = 1.6504e-05
#
#
# Solver failed (15/15): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.5179e-04
# Iteration 1000: Loss = 3.3188e-05
#
#
# Maximum retries reached. Exiting.
# Generated 15110 data from 17 BVP solutions in 756.5 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 1.1126e-05, Loss_V_x = 1.1266e-03, Loss_HJB = 7.1635e-04,  Loss_total = 1.8541e-03
# Iteration 1000: Loss_V = 6.5265e-06, Loss_V_x = 1.8490e-04, Loss_HJB = 1.0222e-04,  Loss_total = 2.9365e-04
# Iteration 2000: Loss_V = 2.8042e-06, Loss_V_x = 1.3373e-04, Loss_HJB = 6.1476e-05,  Loss_total = 1.9801e-04
# Iteration 3000: Loss_V = 5.0356e-06, Loss_V_x = 1.2483e-04, Loss_HJB = 7.6658e-05,  Loss_total = 2.0652e-04
# Iteration 4000: Loss_V = 4.3141e-06, Loss_V_x = 1.0792e-04, Loss_HJB = 5.9850e-05,  Loss_total = 1.7208e-04
# Iteration 5000: Loss_V = 2.1805e-06, Loss_V_x = 1.0324e-04, Loss_HJB = 4.7158e-05,  Loss_total = 1.5258e-04
#
#
# Generating data...
# Generated 10345 data from 32 BVP solutions in 87.6 sec
#
# Training V1 solution of BVP
# Iteration 0: Loss_V = 4.3693e-06, Loss_V_x = 8.6382e-04, Loss_HJB = 7.5768e-04,  Loss_total = 1.6259e-03
# Iteration 1000: Loss_V = 4.9166e-06, Loss_V_x = 2.8330e-04, Loss_HJB = 8.3307e-05,  Loss_total = 3.7152e-04
# Iteration 2000: Loss_V = 3.1023e-06, Loss_V_x = 2.2857e-04, Loss_HJB = 5.0949e-05,  Loss_total = 2.8262e-04
# Iteration 3000: Loss_V = 2.8938e-06, Loss_V_x = 2.0926e-04, Loss_HJB = 7.2501e-05,  Loss_total = 2.8466e-04
# Iteration 4000: Loss_V = 3.0609e-06, Loss_V_x = 1.9057e-04, Loss_HJB = 6.0441e-05,  Loss_total = 2.5407e-04
# Iteration 5000: Loss_V = 3.0481e-06, Loss_V_x = 1.9129e-04, Loss_HJB = 5.8448e-05,  Loss_total = 2.5278e-04
#
#
# Generated 2688 data from 128 IVP solutions in 40.5 sec
#
# Iteration 0:  Loss_G = 6.0850e-02,  Loss_ODE = 1.0407e-01,  Loss_total = 6.1891e-02
# Iteration 1000:  Loss_G = 3.0101e-05,  Loss_ODE = 2.8176e-03,  Loss_total = 5.8276e-05
# Iteration 2000:  Loss_G = 1.4077e-05,  Loss_ODE = 8.2347e-04,  Loss_total = 2.2312e-05
# Iteration 3000:  Loss_G = 1.8276e-05,  Loss_ODE = 6.9968e-04,  Loss_total = 2.5273e-05
# Iteration 4000:  Loss_G = 8.8792e-06,  Loss_ODE = 5.0069e-04,  Loss_total = 1.3886e-05
# Iteration 5000:  Loss_G = 6.6498e-06,  Loss_ODE = 4.3584e-04,  Loss_total = 1.1008e-05
#
#
# Computed J: 1.784672
# Training V2 solution by HJB
# Iteration 0: Loss = 1.7975e-02
# Iteration 1000: Loss = 1.1686e-04
# Iteration 2000: Loss = 6.6987e-05
# Iteration 3000: Loss = 7.4185e-05
# Iteration 4000: Loss = 3.9963e-05
# Iteration 5000: Loss = 7.0591e-05
#
#
# Generating data...
# Solver failed (1/30): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.9572e-03
# Iteration 1000: Loss = 6.3778e-05
#
#
# Solver failed (2/30): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.6303e-04
# Iteration 1000: Loss = 7.3689e-05
#
#
# Solver failed (3/29): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.0020e-03
# Iteration 1000: Loss = 6.8872e-05
#
#
# Solver failed (4/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.5330e-03
# Iteration 1000: Loss = 6.1614e-05
#
#
# Solver failed (5/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.0064e-03
# Iteration 1000: Loss = 9.5101e-05
#
#
# Solver failed (6/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.4642e-03
# Iteration 1000: Loss = 6.4121e-05
#
#
# Solver failed (7/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.8290e-03
# Iteration 1000: Loss = 6.9936e-05
#
#
# Solver failed (8/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.4998e-03
# Iteration 1000: Loss = 4.2491e-05
#
#
# Solver failed (9/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7525e-03
# Iteration 1000: Loss = 3.7219e-05
#
#
# Solver failed (10/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.3130e-03
# Iteration 1000: Loss = 7.4997e-05
#
#
# Solver failed (11/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.9051e-04
# Iteration 1000: Loss = 7.1625e-05
#
#
# Solver failed (12/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.8291e-03
# Iteration 1000: Loss = 4.7448e-05
#
#
# Solver failed (13/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6824e-03
# Iteration 1000: Loss = 1.4530e-04
#
#
# Solver failed (14/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.5620e-03
# Iteration 1000: Loss = 5.2845e-05
#
#
# Solver failed (15/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.7864e-04
# Iteration 1000: Loss = 1.0299e-04
#
#
# Solver failed (16/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.1265e-03
# Iteration 1000: Loss = 7.7768e-05
#
#
# Solver failed (17/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.7871e-03
# Iteration 1000: Loss = 3.6269e-05
#
#
# Solver failed (18/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 9.0371e-04
# Iteration 1000: Loss = 7.1918e-05
#
#
# Solver failed (19/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.6828e-03
# Iteration 1000: Loss = 5.6506e-05
#
#
# Solver failed (20/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.4758e-03
# Iteration 1000: Loss = 5.6543e-05
#
#
# Solver failed (21/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.1028e-03
# Iteration 1000: Loss = 6.3522e-05
#
#
# Solver failed (22/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.8721e-03
# Iteration 1000: Loss = 6.2468e-05
#
#
# Solver failed (23/23): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.2137e-03
# Iteration 1000: Loss = 6.7345e-05
#
#
# Maximum retries reached. Exiting.
# Generated 2638 data from 9 BVP solutions in 345.3 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 1.2924e-05, Loss_V_x = 1.9033e-03, Loss_HJB = 7.2236e-03,  Loss_total = 9.1398e-03
# Iteration 1000: Loss_V = 6.8122e-07, Loss_V_x = 1.5177e-04, Loss_HJB = 7.4392e-05,  Loss_total = 2.2684e-04
# Iteration 2000: Loss_V = 5.2539e-07, Loss_V_x = 1.3543e-04, Loss_HJB = 7.8046e-05,  Loss_total = 2.1400e-04
# Iteration 3000: Loss_V = 3.3449e-07, Loss_V_x = 1.2656e-04, Loss_HJB = 7.4196e-05,  Loss_total = 2.0109e-04
# Iteration 4000: Loss_V = 7.5724e-07, Loss_V_x = 1.0373e-04, Loss_HJB = 8.8710e-05,  Loss_total = 1.9319e-04
# Iteration 5000: Loss_V = 4.5491e-07, Loss_V_x = 1.0470e-04, Loss_HJB = 4.9683e-05,  Loss_total = 1.5484e-04
#
#
# Generating data...
# Solver failed (1/12): The maximum number of mesh nodes is exceeded.
# Solver failed (2/12): The maximum number of mesh nodes is exceeded.
# Solver failed (3/12): The maximum number of mesh nodes is exceeded.
# Solver failed (4/12): The maximum number of mesh nodes is exceeded.
# Solver failed (5/12): The maximum number of mesh nodes is exceeded.
# Solver failed (6/12): The maximum number of mesh nodes is exceeded.
# Solver failed (7/12): The maximum number of mesh nodes is exceeded.
# Solver failed (8/12): The maximum number of mesh nodes is exceeded.
# Solver failed (9/12): The maximum number of mesh nodes is exceeded.
# Solver failed (10/12): The maximum number of mesh nodes is exceeded.
# Solver failed (11/12): The maximum number of mesh nodes is exceeded.
# Solver failed (12/12): The maximum number of mesh nodes is exceeded.
# Maximum retries reached. Exiting.
# Generated 2513 data from 20 BVP solutions in 65.5 sec
#
# Training V2 solution of BVP
# Iteration 0: Loss_V = 3.2348e-05, Loss_V_x = 6.6639e-04, Loss_HJB = 6.9710e-03,  Loss_total = 7.6697e-03
# Iteration 1000: Loss_V = 3.4232e-06, Loss_V_x = 1.7473e-04, Loss_HJB = 7.3582e-05,  Loss_total = 2.5173e-04
# Iteration 2000: Loss_V = 2.7875e-06, Loss_V_x = 1.5636e-04, Loss_HJB = 6.9830e-05,  Loss_total = 2.2898e-04
# Iteration 3000: Loss_V = 2.8479e-06, Loss_V_x = 1.2201e-04, Loss_HJB = 4.5080e-05,  Loss_total = 1.6993e-04
# Iteration 4000: Loss_V = 2.5592e-06, Loss_V_x = 1.0400e-04, Loss_HJB = 4.2477e-05,  Loss_total = 1.4904e-04
# Iteration 5000: Loss_V = 2.0851e-06, Loss_V_x = 9.9728e-05, Loss_HJB = 5.5931e-05,  Loss_total = 1.5774e-04
#
#
# Generated 2688 data from 128 IVP solutions in 37.9 sec
#
# Iteration 0:  Loss_G = 3.3057e-02,  Loss_ODE = 2.0781e+00,  Loss_total = 5.3838e-02
# Iteration 1000:  Loss_G = 1.9091e-05,  Loss_ODE = 2.2342e-03,  Loss_total = 4.1432e-05
# Iteration 2000:  Loss_G = 8.9953e-06,  Loss_ODE = 8.2450e-04,  Loss_total = 1.7240e-05
# Iteration 3000:  Loss_G = 2.8719e-05,  Loss_ODE = 1.4963e-03,  Loss_total = 4.3682e-05
# Iteration 4000:  Loss_G = 1.1724e-05,  Loss_ODE = 7.0666e-04,  Loss_total = 1.8791e-05
# Iteration 5000:  Loss_G = 4.0651e-06,  Loss_ODE = 3.8881e-04,  Loss_total = 7.9532e-06
#
#
# Computed V0: 1.626865
# Exploitability: 0.157806
#
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 8.8096e+00
# L2 norm    : 2.0774e+00
# Linf norm  : 5.9675e-01
# ==============================================
#
# Step Time: 1944.2 sec
#
#
# --- Step 5 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 1.5111e-02
# Iteration 1000: Loss = 5.6293e-05
# Iteration 2000: Loss = 6.9647e-05
# Iteration 3000: Loss = 4.0757e-05
# Iteration 4000: Loss = 5.8406e-05
# Iteration 5000: Loss = 5.8053e-05
#
#
# Generating data...
# Solving BVP # 2 ...

# %%
from model import *
from src.problem.prb import Analytic
import numpy as np
from src.problem.prb import Analytic
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm


device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#an = Analytic(device) 

data = np.load('data1.npz')
mu = torch.tensor(data['x'], dtype=torch.float32, device=device).mean(axis=0)
std = torch.sqrt(torch.tensor(data['x'], dtype=torch.float32, device=device).var(axis=0))

act_func=lambda x: torch.relu(x)

G_NN = G_Net(dim=2, ns=128, act_func=act_func, hh=0.5,
                            device=device, mu=mu, std=std,  TT=1).to(device)
    
G_NN.load_state_dict(torch.load('G_NNN_round0_n20.pth'))
# Out:
# <ipython-input-20-b79dbd8e9b0e>:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G_NN.load_state_dict(torch.load('G_NNN_round0_n20.pth'))
# <All keys matched successfully>

# %%
def gen_x0(num_samples, Torch=False):

        mu = np.array([[-0.75, 0.] + [0] * (10 - 2)], dtype=np.float32)
        samples = np.sqrt(0.01) * np.random.randn(num_samples, 10) + mu

        if Torch:
            return torch.tensor(samples, dtype=torch.float32, device=device)
        else:
            return samples

# %%
x = gen_x0(500, Torch=True).cpu().detach().numpy()
np.savez('data10.npz', x=x)

# %%
x_intia = gen_x0(100, Torch=True).cpu().detach().numpy()
#data = np.load('data_plot2.npz')
#x_intia = data['x_intia']
x_int = np.tile(x_intia, (21, 1))
x_test = torch.tensor(x_int, dtype=torch.float32, device=device)

t = torch.linspace(0,1.0, 21)
t_test = t.repeat_interleave(x_intia.shape[0]).view(-1,1)
t_test = torch.tensor(t_test, dtype=torch.float32, device=device)

x_out = G_NN(t_test, x_test).cpu().detach().numpy()
class ObstacleField:
    def __init__(self, linspace_size=100, lam_obstacle=1.0):
        self.linspace_size = linspace_size
        self.env = lambda: None
        self.env.lam_obstacle = lam_obstacle

    def FF_obstacle_func(self, x, y):
        """
        Two-diagonal obstacles confined to the interval [-1, 1] x [-1, 1].
        """
        theta = np.pi / 0.5
        rot_mat = np.array([
            [np.cos(theta), -np.sin(theta)],
            [np.sin(theta),  np.cos(theta)]
        ], dtype=float)

        # Obstacle 1
        center1 = np.array([0., 0.3])
        vec1 = np.array([x, y]) - center1
        vec1 = np.dot(vec1, rot_mat)
        mat1 = np.array([[10, 0], [0, 1]])
        bb1 = np.array([0, 3])
        quad1 = np.dot(vec1, np.dot(mat1, vec1))
        lin1 = np.dot(vec1, bb1)
        out1 = np.clip(-1 * (quad1 + lin1 + 1), a_min=-0.1, a_max=None)

        # Obstacle 2
        center2 = np.array([0., -0.3])
        vec2 = np.array([x, y]) - center2
        vec2 = np.dot(vec2, rot_mat)
        mat2 = np.array([[10, 0], [0, 1]])
        bb2 = np.array([0, -3])
        quad2 = np.dot(vec2, np.dot(mat2, vec2))
        lin2 = np.dot(vec2, bb2)
        out2 = np.clip(-1 * (quad2 + lin2 + 1), a_min=-0.1, a_max=None)

        return out1 + out2

    def _make_obstacle_contours(self):
        self.plot_window_size = 1
        xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        X, Y = np.meshgrid(xlin, ylin)
        vec_func = np.vectorize(self.FF_obstacle_func)
        Z = self.env.lam_obstacle * vec_func(X, Y)
        return X, Y, Z

def plot_trj(X_OUT):
    obstacle_field = ObstacleField()
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()
    timesteps = 20

    fig, ax = plt.subplots(figsize=(8, 6))

    # Fill the interior of obstacles in red
    obstacle_levels = [0.001, np.max(Z_contour)]
    ax.contourf(
        X_contour, Y_contour, Z_contour,
        levels=obstacle_levels,
        colors='red',
        alpha=0.2,
        zorder=2
    )

    # Optional: draw obstacle boundaries
    ax.contour(
        X_contour, Y_contour, Z_contour,
        levels=[0],
        colors='black',
        linewidths=1.5,
        zorder=2
    )

    # Plot trajectory samples
    color = iter(cm.viridis(np.linspace(0, 1.0, timesteps + 1)))
    for time_idx in range(0, timesteps + 1):
        c = next(color)
        plot_sample = X_OUT.reshape(21, 100, 2)[time_idx, :, :]
        alpha = 1 if time_idx in {0, timesteps} else 0.3
        ax.scatter(plot_sample[:, 0], plot_sample[:, 1], color=c, alpha=alpha, zorder=10, s=5)

    # Target marker
    ax.scatter(0.75, 0.0, color="blue", marker="*", s=100)

    # Formatting
    ax.set_title("d = 2", fontsize=14)
    ax.set_xlabel(r'$x_1$', fontsize=14)
    ax.set_ylabel(r'$x_2$', fontsize=14)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.savefig('IGT_GEN_2.png', dpi=300)
    plt.show()
plot_trj(x_out)

# %%
#x_intia = x_intia = gen_x0(50, Torch=True).cpu().detach().numpy()
data = np.load('data_plot2.npz')
x_intia = data['x_intia']
x_int = np.tile(x_intia, (21, 1))
x_test = torch.tensor(x_int, dtype=torch.float32, device=device)

t = torch.linspace(0,1.05, 21)
t_test = t.repeat_interleave(x_intia.shape[0]).view(-1,1)
t_test = torch.tensor(t_test, dtype=torch.float32, device=device)

x_out = G_NN(t_test, x_test).cpu().detach().numpy()
class ObstacleField:
    def __init__(self, linspace_size=100, lam_obstacle=1.0):
        self.linspace_size = linspace_size
        self.env = lambda: None
        self.env.lam_obstacle = lam_obstacle

    def FF_obstacle_func(self, x, y):
        """
        Two-diagonal obstacles confined to the interval [-1, 1] x [-1, 1].
        """
        theta = np.pi / 0.5
        rot_mat = np.array([
            [np.cos(theta), -np.sin(theta)],
            [np.sin(theta),  np.cos(theta)]
        ], dtype=float)

        # Obstacle 1
        center1 = np.array([0., 0.3])
        vec1 = np.array([x, y]) - center1
        vec1 = np.dot(vec1, rot_mat)
        mat1 = np.array([[10, 0], [0, 1]])
        bb1 = np.array([0, 3])
        quad1 = np.dot(vec1, np.dot(mat1, vec1))
        lin1 = np.dot(vec1, bb1)
        out1 = np.clip(-1 * (quad1 + lin1 + 1), a_min=-0.1, a_max=None)

        # Obstacle 2
        center2 = np.array([0., -0.3])
        vec2 = np.array([x, y]) - center2
        vec2 = np.dot(vec2, rot_mat)
        mat2 = np.array([[10, 0], [0, 1]])
        bb2 = np.array([0, -3])
        quad2 = np.dot(vec2, np.dot(mat2, vec2))
        lin2 = np.dot(vec2, bb2)
        out2 = np.clip(-1 * (quad2 + lin2 + 1), a_min=-0.1, a_max=None)

        return out1 + out2

    def _make_obstacle_contours(self):
        self.plot_window_size = 1
        xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        X, Y = np.meshgrid(xlin, ylin)
        vec_func = np.vectorize(self.FF_obstacle_func)
        Z = self.env.lam_obstacle * vec_func(X, Y)
        return X, Y, Z

def plot_trj(X_OUT):
    obstacle_field = ObstacleField()
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()
    timesteps = 20

    fig, ax = plt.subplots(figsize=(8, 6))

    # Fill the interior of obstacles in red
    obstacle_levels = [0.001, np.max(Z_contour)]
    ax.contourf(
        X_contour, Y_contour, Z_contour,
        levels=obstacle_levels,
        colors='red',
        alpha=0.2,
        zorder=2
    )

    # Optional: draw obstacle boundaries
    ax.contour(
        X_contour, Y_contour, Z_contour,
        levels=[0],
        colors='black',
        linewidths=1.5,
        zorder=2
    )

    # Plot trajectory samples
    color = iter(cm.viridis(np.linspace(0, 1.0, timesteps + 1)))
    for time_idx in range(0, timesteps + 1):
        c = next(color)
        plot_sample = X_OUT.reshape(21, 50, 2)[time_idx, :, :]
        alpha = 1 if time_idx in {0, timesteps} else 0.3
        ax.scatter(plot_sample[:, 0], plot_sample[:, 1], color=c, alpha=alpha, zorder=10, s=5)

    # Target marker
    ax.scatter(0.75, 0.0, color="blue", marker="*", s=100)

    # Formatting
    ax.set_title("d = 2", fontsize=14)
    ax.set_xlabel(r'$x_1$', fontsize=14)
    ax.set_ylabel(r'$x_2$', fontsize=14)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.savefig('IGT_GEN_2.png', dpi=300)
    plt.show()
plot_trj(x_out)

# %%
np.savez('data_plot2_50.npz', x_intia=x_intia)

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter, PillowWriter
import imageio_ffmpeg

def animate_trajectory_save_mp4(X_OUT, fps=10):
    """
    Create and save trajectory animation as MP4 in the current working directory.
    Falls back to GIF if ffmpeg is not available.
    
    Parameters:
        X_OUT (np.ndarray or torch.Tensor): Flattened trajectory array of shape [(T+1)*N, 2].
        fps (int): Frames per second for the output video.
    """
    # Initialize obstacle field (ensure ObstacleField is imported in your environment)
    obstacle_field = ObstacleField()
    Xc, Yc, Zc = obstacle_field._make_obstacle_contours()

    # Determine number of timesteps and reshape
    total_points = X_OUT.shape[0]
    # assume N = number of points per frame = total_points / (timesteps+1)
    # here we infer timesteps from X_OUT shape
    # if you know timesteps explicitly, set timesteps directly
    N = X_OUT.shape[1] if X_OUT.ndim > 1 else 2  # fallback if needed
    timesteps = int(total_points / N) - 1
    trajectory_data = X_OUT.reshape(timesteps + 1, -1, 2)

    # Setup plot
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.contour(Xc, Yc, Zc, levels=[0], colors="black", linewidths=2, zorder=1)
    ax.set_title("Trajectory Simulation", fontsize=14)
    ax.set_xlabel("X", fontsize=12)
    ax.set_ylabel("Y", fontsize=12)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)

    scatter = ax.scatter([], [], s=5, zorder=10)

    def update(frame):
        pts = trajectory_data[frame]
        scatter.set_offsets(pts)
        scatter.set_color(plt.cm.rainbow(frame / timesteps))
        return scatter,

    anim = FuncAnimation(fig, update, frames=range(timesteps + 1), blit=True)

    # Filenames in current directory
    cwd = os.getcwd()
    mp4_filename = "trajectory.mp4"
    mp4_path = os.path.join(cwd, mp4_filename)
    gif_filename = "trajectory.gif"
    gif_path = os.path.join(cwd, gif_filename)

    # Try saving as MP4
    try:
        writer = FFMpegWriter(fps=fps, codec='h264', extra_args=['-pix_fmt', 'yuv420p'])
        anim.save(mp4_path, writer=writer)
        plt.close(fig)
        print(f"Animation saved as MP4 in directory: {cwd}")
    except (FileNotFoundError, RuntimeError):
        # Fallback to GIF
        writer = PillowWriter(fps=fps)
        anim.save(gif_path, writer=writer)
        plt.close(fig)
        print(f"ffmpeg not found; animation saved as GIF in directory: {cwd}")

# Example usage:
# animate_trajectory_save_mp4(x_out, fps=20)

# %%
animate_trajectory_save_mp4(x_out, fps=5)
# Out:
# ffmpeg not found; animation saved as GIF in directory: /home/mouhcine.assouli/IGT_GEN_Obstacl_D_new2

# %%
pip install imageio-ffmpeg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.5.1-py3-none-manylinux2010_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: setuptools in /home/mouhcine.assouli/.local/lib/python3.8/site-packages (from imageio-ffmpeg) (69.0.3)
# Downloading imageio_ffmpeg-0.5.1-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 16.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.5.1
#
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: /srv/software/easybuild/software/Anaconda3/2020.11/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import HTML
import os

def animate_trajectory(X_OUT, filename="trajectory.html"):
    # Initialize obstacle field
    obstacle_field = ObstacleField()

    # Generate contours
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()

    timesteps = 20
    trajectory_data = X_OUT.reshape(timesteps + 1, -1, 2)  # Adjust dimensions if needed

    # Plot setup
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.contour(X_contour, Y_contour, Z_contour, levels=[0], colors="black", linewidths=2, zorder=1)
    ax.set_title("Trajectory Simulation", fontsize=14)
    ax.set_xlabel("X", fontsize=12)
    ax.set_ylabel("Y", fontsize=12)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)

    # Plot initialization
    scatter = ax.scatter([], [], s=5, zorder=10)

    # Update function for animation
    def update(frame):
        data = trajectory_data[frame]
        scatter.set_offsets(data)
        scatter.set_color(cm.rainbow(frame / timesteps))
        return scatter,

    # Create animation
    anim = FuncAnimation(fig, update, frames=range(timesteps + 1), blit=True)

    # Export to HTML5 string
    html_str = anim.to_jshtml()

    # Save to file in current directory
    with open(filename, "w") as f:
        f.write(html_str)

    cwd = os.getcwd()
    print(f"Animation HTML saved as '{filename}' in directory: {cwd}")

    plt.close(fig)
    return HTML(html_str)

# %%
animate_trajectory(x_out, filename="trajectory.html")
# Out:
# Animation HTML saved as 'trajectory.html' in directory: /home/mouhcine.assouli/IGT_GEN_Obstacl_D_new2
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgce132b9a2bf9431ba5b97812eb71eceb">
#   <div class="anim-controls">
#     <input id="_anim_sliderce132b9a2bf9431ba5b97812eb71eceb" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animce132b9a2bf9431ba5b97812eb71eceb.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animce132b9a2bf9431ba5b97812eb71eceb.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animce132b9a2bf9431ba5b97812eb71eceb.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animce132b9a2bf9431ba5b97812eb71eceb.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animce132b9a2bf9431ba5b97812eb71eceb.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animce132b9a2bf9431ba5b97812eb71eceb.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animce132b9a2bf9431ba5b97812eb71eceb.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animce132b9a2bf9431ba5b97812eb71eceb.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animce132b9a2bf9431ba5b97812eb71eceb.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animce132b9a2bf9431ba5b97812eb71eceb.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectce132b9a2bf9431ba5b97812eb71eceb"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_ce132b9a2bf9431ba5b97812eb71eceb"
#              >
#       <label for="_anim_radio1_ce132b9a2bf9431ba5b97812eb71eceb">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_ce132b9a2bf9431ba5b97812eb71eceb"
#              checked>
#       <label for="_anim_radio2_ce132b9a2bf9431ba5b97812eb71eceb">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_ce132b9a2bf9431ba5b97812eb71eceb"
#              >
#       <label for="_anim_radio3_ce132b9a2bf9431ba5b97812eb71eceb">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgce132b9a2bf9431ba5b97812eb71eceb";
#     var slider_id = "_anim_sliderce132b9a2bf9431ba5b97812eb71eceb";
#     var loop_select_id = "_anim_loop_selectce132b9a2bf9431ba5b97812eb71eceb";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm


# Assuming ObstacleField is already defined

def animate_trajectory(X_OUT):
    # Initialize obstacle field
    obstacle_field = ObstacleField()

    # Generate contours
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()

    timesteps = 20
    trajectory_data = X_OUT.reshape(timesteps + 1, -1, 2)  # Adjust dimensions if needed

    # Plot setup
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.contour(X_contour, Y_contour, Z_contour, levels=[0], colors="black", linewidths=2, zorder=1)
    ax.set_title("Trajectory Simulation", fontsize=14)
    ax.set_xlabel("X", fontsize=12)
    ax.set_ylabel("Y", fontsize=12)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)

    # Plot initialization
    scatter = ax.scatter([], [], s=5, zorder=10)

    # Update function for animation
    def update(frame):
        data = trajectory_data[frame]
        scatter.set_offsets(data)
        scatter.set_color(cm.rainbow(frame / timesteps))
        return scatter,

    # Create animation
    anim = FuncAnimation(fig, update, frames=range(timesteps + 1), blit=True)
    
    # Generate the HTML representation
    html_str = anim.to_jshtml()

    # Save HTML to file
    with open(filename, "w") as f:
        f.write(html_str)

    plt.close(fig)
    cwd = os.getcwd()
    print(f"Animation HTML saved as in directory")


    # Display animation inline
    return HTML(anim.to_jshtml())


# Generate video
animate_trajectory(x_out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-a14c489a870e> in <module>
#      57
#      58 # Generate video
# ---> 59 animate_trajectory(x_out)
#
# <ipython-input-36-a14c489a870e> in animate_trajectory(X_OUT)
#      44
#      45     # Save HTML to file
# ---> 46     with open(filename, "w") as f:
#      47         f.write(html_str)
#      48
#
# NameError: name 'filename' is not defined

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm


# Assuming ObstacleField is already defined

def animate_trajectory(X_OUT):
    # Initialize obstacle field
    obstacle_field = ObstacleField()

    # Generate contours
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()

    timesteps = 20
    trajectory_data = X_OUT.reshape(timesteps + 1, -1, 2)  # Adjust dimensions if needed

    # Plot setup
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.contour(X_contour, Y_contour, Z_contour, levels=[0], colors="black", linewidths=2, zorder=1)
    ax.set_title("Trajectory Simulation", fontsize=14)
    ax.set_xlabel("X", fontsize=12)
    ax.set_ylabel("Y", fontsize=12)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)

    # Plot initialization
    scatter = ax.scatter([], [], s=5, zorder=10)

    # Update function for animation
    def update(frame):
        data = trajectory_data[frame]
        scatter.set_offsets(data)
        scatter.set_color(cm.rainbow(frame / timesteps))
        return scatter,

    # Create animation
    anim = FuncAnimation(fig, update, frames=range(timesteps + 1), blit=True)

    # Display animation inline
    return HTML(anim.to_jshtml())


# Generate video
animate_trajectory(x_out)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img3d85ea89c18d4444a7c45b5e9b4df836">
#   <div class="anim-controls">
#     <input id="_anim_slider3d85ea89c18d4444a7c45b5e9b4df836" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim3d85ea89c18d4444a7c45b5e9b4df836.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim3d85ea89c18d4444a7c45b5e9b4df836.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select3d85ea89c18d4444a7c45b5e9b4df836"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_3d85ea89c18d4444a7c45b5e9b4df836"
#              >
#       <label for="_anim_radio1_3d85ea89c18d4444a7c45b5e9b4df836">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_3d85ea89c18d4444a7c45b5e9b4df836"
#              checked>
#       <label for="_anim_radio2_3d85ea89c18d4444a7c45b5e9b4df836">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_3d85ea89c18d4444a7c45b5e9b4df836"
#              >
#       <label for="_anim_radio3_3d85ea89c18d4444a7c45b5e9b4df836">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3d85ea89c18d4444a7c45b5e9b4df836";
#     var slider_id = "_anim_slider3d85ea89c18d4444a7c45b5e9b4df836";
#     var loop_select_id = "_anim_loop_select3d85ea89c18d4444a7c45b5e9b4df836";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %%
# %run main.py 
#dim=4
# Out:
# ========= Round 2 =========
#
#
# --- Step 0 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 3.4470e+01
# Iteration 1000: Loss = 4.2137e+00
# Iteration 2000: Loss = 1.2873e+00
# Iteration 3000: Loss = 3.1442e-01
# Iteration 4000: Loss = 1.0356e-01
# Iteration 5000: Loss = 9.2699e-02
#
#
# Generating data...
# Solver failed (1/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.1897e-01
# Iteration 1000: Loss = 1.6311e-02
#
#
# Solver failed (2/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 3.4618e-02
# Iteration 1000: Loss = 9.8638e-03
#
#
# Solver failed (3/31): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 1.3706e-01
# Iteration 1000: Loss = 5.7075e-03
#
#
# Solver failed (4/30): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 2.1375e-02
# Iteration 1000: Loss = 6.7636e-03
#
#
# Solver failed (5/30): The maximum number of mesh nodes is exceeded.
# Iteration 0: Loss = 4.4546e-02

# %%
# %run main.py
# Out:
# ========= Round 2 =========
#
#
# --- Step 0 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 3.9766e+01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/IGT_GEN_Obstacl_D/main.py in <module>
#     146
#     147 if __name__ == "__main__":
# --> 148     main()
#     149
#     150     # Restore stdout
#
# ~/IGT_GEN_Obstacl_D/main.py in main()
#     110
#     111             an = Analytic(G_NN_list, Round, n, x0_ini, device, VV=1)
# --> 112             V_NN = train_v_nn(an, V_NN, args.num_epoch_v, args.num_epoch_hjb, t, args.lr_v, args.num_samples_hjb, args.num_samples_bvp, Round, device, VV=1)
#     113
#     114             try:
#
# ~/IGT_GEN_Obstacl_D/src/solve.py in train_v_nn(an, V_NN, num_epochs, num_epoch_hjb, t, lr_v, num_samples_hjb, num_samples_bvp, round_num, device, VV)
#     465 #     if  an.n == 0 and VV==1:
#     466     print(f"Training V{VV} solution by HJB")
# --> 467     V_NN = Solve_HJB(an, V_NN, num_epoch_hjb, t, lr_v, num_samples_hjb, device)
#     468
#     469     attempts, Ns_sol = 0, 0
#
# ~/IGT_GEN_Obstacl_D/src/solve.py in Solve_HJB(an, V_NN, num_epoch, t, lr, num_samples, device)
#      96                                           create_graph=True, retain_graph=True, only_inputs=True)[0]
#      97
# ---> 98       V_nn_x = torch.autograd.grad(outputs=V_nn, inputs=x_rand,
#      99                                           grad_outputs=torch.ones_like(V_nn),
#     100                                           create_graph=True, retain_graph=True, only_inputs=True)[0]
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     274         return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     275     else:
# --> 276         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     277             t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     278             allow_unused, accumulate_grad=False)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
# torch.Size([264, 2])
# torch.Size([264, 4])

# %%
from model import *
from src.problem.prb import Analytic
import numpy as np
from src.problem.prb import Analytic
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#an = Analytic(device) 

data = np.load('data2.npz')
mu = torch.tensor(data['x'], dtype=torch.float32, device=device).mean(axis=0)
std = torch.sqrt(torch.tensor(data['x'], dtype=torch.float32, device=device).var(axis=0))

act_func=lambda x: torch.relu(x)

G_NN = G_Net(dim=4, ns=128, act_func=act_func, hh=0.5,
                            device=device, mu=mu, std=std,  TT=1).to(device)
    
G_NN.load_state_dict(torch.load('G_NN2_round2_n8.pth'))
# Out:
# <All keys matched successfully>

# %%
def gen_x0(num_samples, Torch=False):

        mu = np.array([[-0.75, 0.] + [0] * (4 - 2)], dtype=np.float32)
        samples = np.sqrt(0.01) * np.random.randn(num_samples, 4) + mu

        if Torch:
            return torch.tensor(samples, dtype=torch.float32, device=device)
        else:
            return samples

# %%
x_intia = gen_x0(50, Torch=True).cpu().detach().numpy()
x_int = np.tile(x_intia, (21, 1))
x_test = torch.tensor(x_int, dtype=torch.float32, device=device)

t = torch.linspace(0,1.0, 21)
t_test = t.repeat_interleave(x_intia.shape[0]).view(-1,1)
t_test = torch.tensor(t_test, dtype=torch.float32, device=device)

x_out = G_NN(t_test, x_test).cpu().detach().numpy()

# %%
class ObstacleField:
    def __init__(self, linspace_size=100, lam_obstacle=1.0):
        self.linspace_size = linspace_size
        self.env = lambda: None
        self.env.lam_obstacle = lam_obstacle

    def circular_obstacle(self, x, y, center, radius):
        """
        Defines a circular obstacle.
        """
        dist_squared = (x - center[0])**2 + (y - center[1])**2
        return radius**2 - dist_squared

    def smooth_max(self, f1, f2, smoothness=50.0):
        return (1 / smoothness) * np.log(np.exp(smoothness * f1) + np.exp(smoothness * f2))

#     def FF_obstacle_func(self, x, y):
#         """
#         Combines two circular obstacles with smooth maximum.
#         """
#         obstacle1 = self.circular_obstacle(x, y, center=[0., 0.65], radius=0.5)
#         obstacle2 = self.circular_obstacle(x, y, center=[0., -0.65], radius=0.5)

# #         obstacle1 = self.circular_obstacle(x, y, center=[0.1, 0.6], radius=0.5)
# #         obstacle2 = self.circular_obstacle(x, y, center=[0.1, -0.7], radius=0.7)
#         return np.maximum(obstacle1, obstacle2)

    def FF_obstacle_func(self, x, y):
        """
        Two-diagonal obstacles confined to the interval [-1, 1] x [-1, 1].
        """
        # Rotation matrix for diagonal obstacles (rotated by 36 degrees)
        theta = np.pi / 0.5
        rot_mat = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]], dtype=float)

        # Bottom/Left obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center1 = np.array([-0., 0.3], dtype=float)  # Center shifted within [-1, 1]
        vec1 = np.array([x, y], dtype=float) - center1
        vec1 = np.dot(vec1, rot_mat)  # Apply rotation
        mat1 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb1 = np.array([0, 3], dtype=float)  # Adjust slope/linear term
        quad1 = np.dot(vec1, np.dot(mat1, vec1))
        lin1 = np.dot(vec1, bb1)
        out1 = np.clip((-1) * (quad1 + lin1 + 1), a_min=-0.1, a_max=None)

        # Top/Right obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center2 = np.array([0., -0.3], dtype=float)  # Center shifted within [-1, 1]
        vec2 = np.array([x, y], dtype=float) - center2
        vec2 = np.dot(vec2, rot_mat)  # Apply rotation
        mat2 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb2 = np.array([0, -3], dtype=float)  # Adjust slope/linear term
        quad2 = np.dot(vec2, np.dot(mat2, vec2))
        lin2 = np.dot(vec2, bb2)
        out2 = np.clip((-1) * (quad2 + lin2 + 1), a_min=-0.1, a_max=None)

        # Combine the two obstacles
        out = out1 + out2

        return out
    
    def _make_obstacle_contours(self):
        """
        Precomputes the obstacle contour.
        """
        self.plot_window_size = 1  # plot window size
        xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        X, Y = np.meshgrid(xlin, ylin)
        vec_func = np.vectorize(self.FF_obstacle_func)
        Z = self.env.lam_obstacle * vec_func(X, Y)

        return X, Y, Z

#     def _make_obstacle_contours(self):
#         """
#         Prepares contour grid for obstacle field visualization.
#         """
#         self.plot_window_size = 1.5
#         xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
#         ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
#         X, Y = np.meshgrid(xlin, ylin)
#         vec_func = np.vectorize(self.FF_obstacle_func)
#         Z = self.env.lam_obstacle * vec_func(X, Y)
#         return X, Y, Z

def plot_trj(X_OUT):
    # Initialize obstacle field
    obstacle_field = ObstacleField()

    # Generate contours
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()

    timesteps = 20

    # Define obstacle properties
#     obstacles = [
#         {"center": [0., 0.65], "radius": 0.5},
#         {"center": [0., -0.65], "radius": 0.5},
#     ]

    # Plot setup
    fig, ax = plt.subplots(figsize=(8, 6))

    # Add contour lines for obstacles
    ax.contour(
        X_contour, Y_contour, Z_contour, 
        levels=[0], 
        colors="black", 
        linewidths=2, 
        zorder=1
    )

    # Add filled circles for obstacles
#     for obs in obstacles:
#         circle = plt.Circle(obs["center"], obs["radius"], color="red", alpha=0.2, zorder=2)
#         ax.add_patch(circle)

    # Plot the trajectory
    color = iter(cm.rainbow(np.linspace(0, 1.0, timesteps + 1)))
    #next(color)  # Skip the first color

    for time_idx in range(0, timesteps + 1):
        c = next(color)
        plot_sample = X_OUT.reshape(21, 50, 4)[time_idx, : , :]  # Adjust for trajectory dimensions
        alpha = 1 if time_idx in {0, timesteps} else 0.3
        ax.scatter(plot_sample[:, 0], plot_sample[:, 1], color=c, alpha=alpha, zorder=10, s=5)

    # Mark specific points
    #ax.scatter(6.95185290e-01, -2.03101843e-02, color="blue", marker="x", s=100)
    ax.scatter(0.75, 0.0, color="blue", marker="*", s=100)

    # Adjust plot limits and labels
    ax.set_title("Trajectory with Circular Obstacles (d=2)", fontsize=14)
    ax.set_xlabel("X", fontsize=12)
    ax.set_ylabel("Y", fontsize=12)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)

    # Save and display the plot
    plt.savefig("trajectory_with_obstacles.png", dpi=300)
    #plt.show()

# %%
plot_trj(x_out)

# %%
# %run main.py
#dim=10
# Out:
# ========= Round 2 =========
#
#
# --- Step 0 ---
#
# Training V1 solution by HJB
# Iteration 0: Loss = 4.8678e+01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/IGT_GEN_Obstacl_D/main.py in <module>
#     149
#     150 if __name__ == "__main__":
# --> 151     main()
#     152
#     153     # Restore stdout
#
# ~/IGT_GEN_Obstacl_D/main.py in main()
#     110
#     111             an = Analytic(G_NN_list, Round, n, x0_ini, device, VV=1)
# --> 112             V_NN = train_v_nn(an, V_NN, args.num_epoch_v, args.num_epoch_hjb, t, args.lr_v, args.num_samples_hjb, args.num_samples_bvp, Round, device, VV=1)
#     113
#     114             try:
#
# ~/IGT_GEN_Obstacl_D/src/solve.py in train_v_nn(an, V_NN, num_epochs, num_epoch_hjb, t, lr_v, num_samples_hjb, num_samples_bvp, round_num, device, VV)
#     465 #     if  an.n == 0 and VV==1:
#     466     print(f"Training V{VV} solution by HJB")
# --> 467     V_NN = Solve_HJB(an, V_NN, num_epoch_hjb, t, lr_v, num_samples_hjb, device)
#     468
#     469     attempts, Ns_sol = 0, 0
#
# ~/IGT_GEN_Obstacl_D/src/solve.py in Solve_HJB(an, V_NN, num_epoch, t, lr, num_samples, device)
#      96                                           create_graph=True, retain_graph=True, only_inputs=True)[0]
#      97
# ---> 98       V_nn_x = torch.autograd.grad(outputs=V_nn, inputs=x_rand,
#      99                                           grad_outputs=torch.ones_like(V_nn),
#     100                                           create_graph=True, retain_graph=True, only_inputs=True)[0]
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     274         return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     275     else:
# --> 276         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     277             t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     278             allow_unused, accumulate_grad=False)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
from model import *
from src.problem.prb import Analytic
import numpy as np
from src.problem.prb import Analytic
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib import cm
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#an = Analytic(device) 

data = np.load('data3.npz')
mu = torch.tensor(data['x'], dtype=torch.float32, device=device).mean(axis=0)
std = torch.sqrt(torch.tensor(data['x'], dtype=torch.float32, device=device).var(axis=0))

act_func=lambda x: torch.relu(x)

G_NN = G_Net(dim=10, ns=128, act_func=act_func, hh=0.5,
                            device=device, mu=mu, std=std,  TT=1).to(device)
    
G_NN.load_state_dict(torch.load('G_NN3_round2_n6.pth'))
# Out:
# <All keys matched successfully>

# %%
def gen_x0(num_samples, Torch=False):

        mu = np.array([[-0.75, 0.] + [0] * (10 - 2)], dtype=np.float32)
        samples = np.sqrt(0.01) * np.random.randn(num_samples, 10) + mu

        if Torch:
            return torch.tensor(samples, dtype=torch.float32, device=device)
        else:
            return samples

# %%
data = np.load('data_plot10.npz')
x_intia = data['x_intia']
x_int = np.tile(x_intia, (21, 1))
x_test = torch.tensor(x_int, dtype=torch.float32, device=device)

t = torch.linspace(0,1.0, 21)
t_test = t.repeat_interleave(x_intia.shape[0]).view(-1,1)
t_test = torch.tensor(t_test, dtype=torch.float32, device=device)

x_out = G_NN(t_test, x_test).cpu().detach().numpy()

class ObstacleField:
    def __init__(self, linspace_size=100, lam_obstacle=1.0):
        self.linspace_size = linspace_size
        self.env = lambda: None
        self.env.lam_obstacle = lam_obstacle

    def circular_obstacle(self, x, y, center, radius):
        """
        Defines a circular obstacle.
        """
        dist_squared = (x - center[0])**2 + (y - center[1])**2
        return radius**2 - dist_squared

    def smooth_max(self, f1, f2, smoothness=50.0):
        return (1 / smoothness) * np.log(np.exp(smoothness * f1) + np.exp(smoothness * f2))


    def FF_obstacle_func(self, x, y):
        """
        Two-diagonal obstacles confined to the interval [-1, 1] x [-1, 1].
        """
        # Rotation matrix for diagonal obstacles (rotated by 36 degrees)
        theta = np.pi / 0.5
        rot_mat = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]], dtype=float)

        # Bottom/Left obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center1 = np.array([-0., 0.3], dtype=float)  # Center shifted within [-1, 1]
        vec1 = np.array([x, y], dtype=float) - center1
        vec1 = np.dot(vec1, rot_mat)  # Apply rotation
        mat1 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb1 = np.array([0, 3], dtype=float)  # Adjust slope/linear term
        quad1 = np.dot(vec1, np.dot(mat1, vec1))
        lin1 = np.dot(vec1, bb1)
        out1 = np.clip((-1) * (quad1 + lin1 + 1), a_min=-0.1, a_max=None)

        # Top/Right obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center2 = np.array([0., -0.3], dtype=float)  # Center shifted within [-1, 1]
        vec2 = np.array([x, y], dtype=float) - center2
        vec2 = np.dot(vec2, rot_mat)  # Apply rotation
        mat2 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb2 = np.array([0, -3], dtype=float)  # Adjust slope/linear term
        quad2 = np.dot(vec2, np.dot(mat2, vec2))
        lin2 = np.dot(vec2, bb2)
        out2 = np.clip((-1) * (quad2 + lin2 + 1), a_min=-0.1, a_max=None)

        # Combine the two obstacles
        out = out1 + out2

        return out
    
    def _make_obstacle_contours(self):
        """
        Precomputes the obstacle contour.
        """
        self.plot_window_size = 1  # plot window size
        xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        X, Y = np.meshgrid(xlin, ylin)
        vec_func = np.vectorize(self.FF_obstacle_func)
        Z = self.env.lam_obstacle * vec_func(X, Y)

        return X, Y, Z

def plot_trj(X_OUT):
    obstacle_field = ObstacleField()
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()
    timesteps = 20

    fig, ax = plt.subplots(figsize=(8, 6))

    # Fill the interior of obstacles in red
    obstacle_levels = [0.001, np.max(Z_contour)]
    ax.contourf(
        X_contour, Y_contour, Z_contour,
        levels=obstacle_levels,
        colors='red',
        alpha=0.2,
        zorder=2
    )

    # Optional: draw obstacle boundaries
    ax.contour(
        X_contour, Y_contour, Z_contour,
        levels=[0],
        colors='black',
        linewidths=1.5,
        zorder=2
    )

    # Plot trajectory samples
    color = iter(cm.viridis(np.linspace(0, 1.0, timesteps + 1)))
    for time_idx in range(0, timesteps + 1):
        c = next(color)
        plot_sample = X_OUT.reshape(21, 50, 10)[time_idx, :, :]
        alpha = 1 if time_idx in {0, timesteps} else 0.3
        ax.scatter(plot_sample[:, 0], plot_sample[:, 1], color=c, alpha=alpha, zorder=10, s=5)

    # Target marker
    ax.scatter(0.75, 0.0, color="blue", marker="*", s=100)

    # Formatting
    ax.set_title("d = 10", fontsize=14)
    ax.set_xlabel(r'$x_1$', fontsize=14)
    ax.set_ylabel(r'$x_2$', fontsize=14)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.savefig('IGT_GEN_10.png', dpi=300)
    plt.show()
plot_trj(x_out)

# %%
class ObstacleField:
    def __init__(self, linspace_size=100, lam_obstacle=1.0):
        self.linspace_size = linspace_size
        self.env = lambda: None
        self.env.lam_obstacle = lam_obstacle

    def circular_obstacle(self, x, y, center, radius):
        """
        Defines a circular obstacle.
        """
        dist_squared = (x - center[0])**2 + (y - center[1])**2
        return radius**2 - dist_squared

    def smooth_max(self, f1, f2, smoothness=50.0):
        return (1 / smoothness) * np.log(np.exp(smoothness * f1) + np.exp(smoothness * f2))

    def FF_obstacle_func(self, x, y):
        """
        Combines two circular obstacles with smooth maximum.
        """
        obstacle1 = self.circular_obstacle(x, y, center=[0., 0.65], radius=0.5)
        obstacle2 = self.circular_obstacle(x, y, center=[0, -0.65], radius=0.5)

#         obstacle1 = self.circular_obstacle(x, y, center=[0.1, 0.6], radius=0.5)
#         obstacle2 = self.circular_obstacle(x, y, center=[0.1, -0.7], radius=0.7)
        return np.maximum(obstacle1, obstacle2)

    def _make_obstacle_contours(self):
        """
        Prepares contour grid for obstacle field visualization.
        """
        self.plot_window_size = 1.5
        xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        X, Y = np.meshgrid(xlin, ylin)
        vec_func = np.vectorize(self.FF_obstacle_func)
        Z = self.env.lam_obstacle * vec_func(X, Y)
        return X, Y, Z


# Initialize obstacle field
obstacle_field = ObstacleField()

# Generate contours
X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()

timesteps = 20

# Define obstacle properties
obstacles = [
    {"center": [0., 0.65], "radius": 0.5},
    {"center": [0., -0.65], "radius": 0.5},
]

# Plot setup
fig, ax = plt.subplots(figsize=(8, 6))

# Add contour lines for obstacles
ax.contour(
    X_contour, Y_contour, Z_contour, 
    levels=[0], 
    colors="black", 
    linewidths=2, 
    zorder=1
)

# Add filled circles for obstacles
for obs in obstacles:
    circle = plt.Circle(obs["center"], obs["radius"], color="red", alpha=0.2, zorder=2)
    ax.add_patch(circle)

# Plot the trajectory
color = iter(cm.rainbow(np.linspace(0, 1, timesteps + 2)))
next(color)  # Skip the first color

# for time_idx in range(0, timesteps + 1):
#     c = next(color)
#     plot_sample = X_OUT.reshape(128, 21, 2)[0:64, time_idx, :]  # Adjust for trajectory dimensions
#     alpha = 1 if time_idx in {0, timesteps} else 0.3
#     ax.scatter(plot_sample[:, 0], plot_sample[:, 1], color=c, alpha=alpha, zorder=10, s=5)

# Mark specific points
ax.scatter(0.5, 1., color="blue", marker="x", s=100)

# Adjust plot limits and labels
ax.set_title("Trajectory with Circular Obstacles (d=2)", fontsize=14)
ax.set_xlabel("X", fontsize=12)
ax.set_ylabel("Y", fontsize=12)
ax.axis("equal")
ax.grid(True, linestyle="--", alpha=0.5)

# Save and display the plot
plt.savefig("trajectory_with_obstacles.png", dpi=300)
#plt.show()

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

class ObstacleField:
    def __init__(self, linspace_size=100, lam_obstacle=1.0):
        self.linspace_size = linspace_size
        self.env = lambda: None
        self.env.lam_obstacle = lam_obstacle
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    def smooth_clamp_min(self, x, smoothness=20.0):
        return (1 / smoothness) * np.log(1 + np.exp(smoothness * x))

    def FF_obstacle_func(self, x, y):
        """
        Two-diagonal obstacles confined to the interval [-1, 1] x [-1, 1].
        """
        # Rotation matrix for diagonal obstacles (rotated by 36 degrees)
        theta = np.pi / 5
        rot_mat = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]], dtype=float)

        # Bottom/Left obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center1 = np.array([-0.9, 0.2], dtype=float)  # Center shifted within [-1, 1]
        vec1 = np.array([x, y], dtype=float) - center1
        vec1 = np.dot(vec1, rot_mat)  # Apply rotation
        mat1 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb1 = np.array([0, 3], dtype=float)  # Adjust slope/linear term
        quad1 = np.dot(vec1, np.dot(mat1, vec1))
        lin1 = np.dot(vec1, bb1)
        out1 = np.clip((-1) * (quad1 + lin1 + 1), a_min=-0.1, a_max=None)

        # Top/Right obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center2 = np.array([0.9, -0.2], dtype=float)  # Center shifted within [-1, 1]
        vec2 = np.array([x, y], dtype=float) - center2
        vec2 = np.dot(vec2, rot_mat)  # Apply rotation
        mat2 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb2 = np.array([0, -3], dtype=float)  # Adjust slope/linear term
        quad2 = np.dot(vec2, np.dot(mat2, vec2))
        lin2 = np.dot(vec2, bb2)
        out2 = np.clip((-1) * (quad2 + lin2 + 1), a_min=-0.1, a_max=None)

        # Combine the two obstacles
        out = out1 + out2

        return out

    def _make_obstacle_contours(self):
        """
        Precomputes the obstacle contour in the interval [-1, 1] x [-1, 1].
        """
        xlin = np.linspace(-2, 2, self.linspace_size)  # Constrain to [-1, 1]
        ylin = np.linspace(-2, 2, self.linspace_size)
        X, Y = np.meshgrid(xlin, ylin)

        vec_func = np.vectorize(lambda x, y: self.FF_obstacle_func(x, y))
        Z = self.env.lam_obstacle * vec_func(X, Y)

        return X, Y, Z


# Initialize ObstacleField
obstacle_field = ObstacleField(lam_obstacle=10)

# Generate contours
X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()

# Plot setup
fig, ax = plt.subplots(figsize=(8, 6))
contour = ax.contour(X_contour, Y_contour, Z_contour, levels=[0], colors='black', linewidths=2, zorder=1)

# Adjust plot
ax.set_title("Two-Diagonal Obstacles in [-1, 1] x [-1, 1]", fontsize=12)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.axis("equal")
ax.grid(True, linestyle="--", alpha=0.3)

# Save and show the plot
plt.savefig('two_diagonal_obstacles.png', dpi=300)
plt.show()

# x = torch.tensor([[-0, -1]], dtype=torch.float)
# print(F_obstacle_func_loss(x))

# %%
import torch

# Define the smooth function
def smooth_clamp_minn(x):
    return torch.nn.functional.softplus(x)


def smooth_clamp_min( x, smoothness=40.0):

        return (1 / smoothness) * torch.log(1 + torch.exp(smoothness * x))

# Example usage
x = torch.tensor([-8.0, -1.0, 0.0, 1.0, 3.0])
print(torch.clamp_min(x, min=0))
print(smooth_clamp_min(x))
# Out:
# tensor([3.3541e-04, 3.1326e-01, 6.9315e-01, 1.3133e+00, 3.0486e+00])
# tensor([0., 0., 0., 1., 3.])
# tensor([0.0000, 0.0000, 0.0173, 1.0000,    inf])

# %%
a = torch.tensor([[2., 1., 1., 1., 1.],
        [3., 1., 1., 1., 1.],
        [5., 1., 1., 1., 1.]])

b = torch.tensor([[0.],
        [2.],
        [3.]])

# %%
a+b
# Out:
# tensor([[2., 1., 1., 1., 1.],
#         [5., 3., 3., 3., 3.],
#         [8., 4., 4., 4., 4.]])

# %%
np.exp(-0.)
# Out:
# 1.0

# %%
# %run main.py
# Out:
# ========= Round 0 =========
#
#
# --- Step 0 ---
#
# Training V1 solution by HJB
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/IGT_GEN_Obstacl_D/main.py in <module>
#     273
#     274 if __name__ == "__main__":
# --> 275     main()
#     276
#     277
#
# ~/IGT_GEN_Obstacl_D/main.py in main()
#     230
#     231             an = Analytic(G_NN_list, Round, n, x0_ini, device, VV=1)
# --> 232             V_NN = train_v_nn(an, V_NN, args.num_epoch_v, args.num_epoch_hjb, t, args.lr_v, args.num_samples_hjb, args.num_samples_bvp, Round, device, VV=1)
#     233
#     234             # Load simulated data
#
# ~/IGT_GEN_Obstacl_D/src/solve.py in train_v_nn(an, V_NN, num_epochs, num_epoch_hjb, t, lr_v, num_samples_hjb, num_samples_bvp, round_num, device, VV)
#     417 #     if  an.n == 0 and VV==1:
#     418     print(f"Training V{VV} solution by HJB")
# --> 419     V_NN = Solve_HJB(an, V_NN, num_epoch_hjb, t, lr_v, num_samples_hjb, device)
#     420
#     421     attempts, Ns_sol = 0, 0
#
# ~/IGT_GEN_Obstacl_D/src/solve.py in Solve_HJB(an, V_NN, num_epoch, t, lr, num_samples, device)
#      89       t = t.requires_grad_(True)
#      90
# ---> 91       V_nn =  V_NN(t, x_rand)
#      92
#      93       V_nn_t = torch.autograd.grad(outputs=V_nn, inputs=t,
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/IGT_GEN_Obstacl_D/model.py in forward(self, t, inp)
#      29         out = torch.cat((t, inp), dim=1)
#      30         out = self.act_func(self.lin1(out))
# ---> 31         out = self.act_func(out + self.hh * self.lin2(out))
#      32         out = self.act_func(out + self.hh * self.lin3(out))
#      33         out = self.linlast(out)
#
# RuntimeError: The size of tensor a (100) must match the size of tensor b (128) at non-singleton dimension 1

# %%
 J = torch.mean(1/(t.shape[0]-1) * )   torch.sum(l[0:t.shape[0]-1, :], dim=0

# %%
import numpy as np

def gen_x0( num_samples, Torch=False):

    mu = np.array([[-0.75, 0] + [0] * (2 - 2)], dtype=np.float32)
    samples = np.sqrt(0.005) * np.random.randn(num_samples, 2) + mu

    if Torch:
        return torch.tensor(samples, dtype=torch.float32, device=self.device)
    else:
        return samples
        
x = gen_x0(264)

np.savez('data.npz', x=x)

# %%
data = np.load('data1.npz')
x0_ini = torch.tensor(data['x'], dtype=torch.float32, device=device)
print(x0_ini.shape)

# %%
# %run main.py
#G_NN4 for d = 2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/IGT_GEN_Obstacl_D/main.py in <module>
#      81 # ==========================
#      82 data = np.load('data1.npz')
# ---> 83 x0_ini = torch.tensor(data['x'], dtype=torch.float32, device=device)
#      84 mu = x0_ini.mean(axis=0)
#      85 std = torch.sqrt(x0_ini.var(axis=0))
#
# KeyboardInterrupt:

# %%
from model import *
from src.problem.prb import Analytic
import numpy as np
from src.problem.prb import Analytic
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#an = Analytic(device) 

data = np.load('data1.npz')
mu = torch.tensor(data['x'], dtype=torch.float32, device=device).mean(axis=0)
std = torch.sqrt(torch.tensor(data['x'], dtype=torch.float32, device=device).var(axis=0))

act_func=lambda x: torch.relu(x)

G_NN = G_Net(dim=2, ns=128, act_func=act_func, hh=0.5,
                            device=device, mu=mu, std=std,  TT=1).to(device)
    
G_NN.load_state_dict(torch.load('G_NN4_round0_n12.pth'))
# Out:
# <All keys matched successfully>

# %%
def gen_x0(num_samples, Torch=False):

        mu = np.array([[-0.75, 0.] + [0] * (2 - 2)], dtype=np.float32)
        samples = np.sqrt(0.01) * np.random.randn(num_samples, 2) + mu

        if Torch:
            return torch.tensor(samples, dtype=torch.float32, device=device)
        else:
            return samples

# %%
x_intia = gen_x0(100, Torch=True).cpu().detach().numpy()
x_int = np.tile(x_intia, (21, 1))
x_test = torch.tensor(x_int, dtype=torch.float32, device=device)

t = torch.linspace(0,1.05, 21)
t_test = t.repeat_interleave(x_intia.shape[0]).view(-1,1)
t_test = torch.tensor(t_test, dtype=torch.float32, device=device)

x_out = G_NN(t_test, x_test).cpu().detach().numpy()

# %%
class ObstacleField:
    def __init__(self, linspace_size=100, lam_obstacle=1.0):
        self.linspace_size = linspace_size
        self.env = lambda: None
        self.env.lam_obstacle = lam_obstacle

    def circular_obstacle(self, x, y, center, radius):
        """
        Defines a circular obstacle.
        """
        dist_squared = (x - center[0])**2 + (y - center[1])**2
        return radius**2 - dist_squared

    def smooth_max(self, f1, f2, smoothness=50.0):
        return (1 / smoothness) * np.log(np.exp(smoothness * f1) + np.exp(smoothness * f2))

#     def FF_obstacle_func(self, x, y):
#         """
#         Combines two circular obstacles with smooth maximum.
#         """
#         obstacle1 = self.circular_obstacle(x, y, center=[0., 0.65], radius=0.5)
#         obstacle2 = self.circular_obstacle(x, y, center=[0., -0.65], radius=0.5)

# #         obstacle1 = self.circular_obstacle(x, y, center=[0.1, 0.6], radius=0.5)
# #         obstacle2 = self.circular_obstacle(x, y, center=[0.1, -0.7], radius=0.7)
#         return np.maximum(obstacle1, obstacle2)

    def FF_obstacle_func(self, x, y):
        """
        Two-diagonal obstacles confined to the interval [-1, 1] x [-1, 1].
        """
        # Rotation matrix for diagonal obstacles (rotated by 36 degrees)
        theta = np.pi / 0.5
        rot_mat = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]], dtype=float)

        # Bottom/Left obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center1 = np.array([-0., 0.3], dtype=float)  # Center shifted within [-1, 1]
        vec1 = np.array([x, y], dtype=float) - center1
        vec1 = np.dot(vec1, rot_mat)  # Apply rotation
        mat1 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb1 = np.array([0, 3], dtype=float)  # Adjust slope/linear term
        quad1 = np.dot(vec1, np.dot(mat1, vec1))
        lin1 = np.dot(vec1, bb1)
        out1 = np.clip((-1) * (quad1 + lin1 + 1), a_min=-0.1, a_max=None)

        # Top/Right obstacle (adjusted center and scaling for [-1, 1] x [-1, 1])
        center2 = np.array([0., -0.3], dtype=float)  # Center shifted within [-1, 1]
        vec2 = np.array([x, y], dtype=float) - center2
        vec2 = np.dot(vec2, rot_mat)  # Apply rotation
        mat2 = np.array([[10, 0], [0, 1]], dtype=float)  # Adjust scaling for [-1, 1]
        bb2 = np.array([0, -3], dtype=float)  # Adjust slope/linear term
        quad2 = np.dot(vec2, np.dot(mat2, vec2))
        lin2 = np.dot(vec2, bb2)
        out2 = np.clip((-1) * (quad2 + lin2 + 1), a_min=-0.1, a_max=None)

        # Combine the two obstacles
        out = out1 + out2

        return out
    
    def _make_obstacle_contours(self):
        """
        Precomputes the obstacle contour.
        """
        self.plot_window_size = 1  # plot window size
        xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
        X, Y = np.meshgrid(xlin, ylin)
        vec_func = np.vectorize(self.FF_obstacle_func)
        Z = self.env.lam_obstacle * vec_func(X, Y)

        return X, Y, Z

#     def _make_obstacle_contours(self):
#         """
#         Prepares contour grid for obstacle field visualization.
#         """
#         self.plot_window_size = 1.5
#         xlin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
#         ylin = np.linspace(-self.plot_window_size, self.plot_window_size, self.linspace_size)
#         X, Y = np.meshgrid(xlin, ylin)
#         vec_func = np.vectorize(self.FF_obstacle_func)
#         Z = self.env.lam_obstacle * vec_func(X, Y)
#         return X, Y, Z

def plot_trj(X_OUT):
    # Initialize obstacle field
    obstacle_field = ObstacleField()

    # Generate contours
    X_contour, Y_contour, Z_contour = obstacle_field._make_obstacle_contours()

    timesteps = 20

    # Define obstacle properties
#     obstacles = [
#         {"center": [0., 0.65], "radius": 0.5},
#         {"center": [0., -0.65], "radius": 0.5},
#     ]

    # Plot setup
    fig, ax = plt.subplots(figsize=(8, 6))

    # Add contour lines for obstacles
    ax.contour(
        X_contour, Y_contour, Z_contour, 
        levels=[0], 
        colors="black", 
        linewidths=2, 
        zorder=1
    )

    # Add filled circles for obstacles
#     for obs in obstacles:
#         circle = plt.Circle(obs["center"], obs["radius"], color="red", alpha=0.2, zorder=2)
#         ax.add_patch(circle)

    # Plot the trajectory
    color = iter(cm.rainbow(np.linspace(0, 1.0, timesteps + 1)))
    #next(color)  # Skip the first color

    for time_idx in range(0, timesteps + 1):
        c = next(color)
        plot_sample = X_OUT.reshape(21, 100, 2)[time_idx, : , :]  # Adjust for trajectory dimensions
        alpha = 1 if time_idx in {0, timesteps} else 0.3
        ax.scatter(plot_sample[:, 0], plot_sample[:, 1], color=c, alpha=alpha, zorder=10, s=5)

    # Mark specific points
    #ax.scatter(6.95185290e-01, -2.03101843e-02, color="blue", marker="x", s=100)
    ax.scatter(0.75, 0.0, color="blue", marker="*", s=100)

    # Adjust plot limits and labels
    ax.set_title("Trajectory with Circular Obstacles (d=2)", fontsize=14)
    ax.set_xlabel("X", fontsize=12)
    ax.set_ylabel("Y", fontsize=12)
    ax.axis("equal")
    ax.grid(True, linestyle="--", alpha=0.5)

    # Save and display the plot
    plt.savefig("trajectory_with_obstacles.png", dpi=300)
    #plt.show()

# %%
plot_trj(x_out)

# %%
import numpy as np
data = np.load('data1.npz')
data['x'].shape
# Out:
# (264, 2)

# %%
def wasserstein_distance_d(model1, model2, t, x0, p=1):

    # Expand grid
    t_expanded = t.repeat_interleave(x0.shape[0]).view(-1,1)    # (T*N, 1)
    x0_expanded = x0.repeat(t.shape[0], 1)                   # (T*N, d)
    

    # Evaluate both models: output should be in R^d
    M1 = model1(t_expanded, x0_expanded).reshape(t.shape[0], x0.shape[0], -1)
    M2 = model2(t_expanded, x0_expanded).reshape(t.shape[0], x0.shape[0], -1)

    # Convert to numpy
    M1_np = M1.detach().cpu().numpy()  # shape (T, N, d)
    M2_np = M2.detach().cpu().numpy()  # shape (T, N, d)

    # Uniform weights
    N = x0.shape[0]
    a = b = np.ones((N,)) / N

    # Compute Wasserstein distance at each time step
    distances = []
    for i in range(M1_np.shape[0]):
        # Cost matrix between samples at time t_i
        C = ot.dist(M1_np[i], M2_np[i], metric='euclidean') ** p
        # Compute EMD
        Wp = ot.emd2(a, b, C)
        distances.append(Wp**(1/p))  # take p-th root

    distances = np.array(distances)

    # Norms over time
    norm_l1 = np.linalg.norm(distances, ord=1)
    norm_l2 = np.linalg.norm(distances, ord=2)
    norm_linf = np.linalg.norm(distances, ord=np.inf)

    # Output
    print("\n=== Wasserstein-p Distance Norms over Time ===")
    print(f"L1 norm    : {norm_l1:.4e}")
    print(f"L2 norm    : {norm_l2:.4e}")
    print(f"Linf norm  : {norm_linf:.4e}")
    print("==============================================\n")

# %%
def gen_x0(num_samples, Torch=False):

        mu = np.array([[-0.75, 0.] + [0] * (2 - 2)], dtype=np.float32)
        samples = np.sqrt(0.01) * np.random.randn(num_samples, 2) + mu

        if Torch:
            return torch.tensor(samples, dtype=torch.float32, device=device)
        else:
            return samples

# %%
x_intia = x_intia = gen_x0(264, Torch=True)

# %%
from model import *
from src.problem.prb import Analytic
import numpy as np
from src.problem.prb import Analytic
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import ot


device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
if device == torch.device('cpu'):
    print('NOTE: USING ONLY THE CPU')



device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#an = Analytic(device) 

# data = np.load('data1.npz')
mu = x_intia.mean(axis=0)
std = torch.sqrt(x_intia.var(axis=0))

act_func=lambda x: torch.relu(x)

G_NN = G_Net(dim=2, ns=128, act_func=act_func, hh=0.5,
                            device=device, mu=mu, std=std,  TT=1).to(device)

G_NN2 = G_Net(dim=2, ns=128, act_func=act_func, hh=0.5,
                            device=device, mu=mu, std=std,  TT=1).to(device)
    
G_NN.load_state_dict(torch.load('G_NNN_round1_n9.pth'))
G_NN2.load_state_dict(torch.load('G_NNN2_round1_n9.pth'))

t=torch.linspace(0, 1, 21, device=device)

# %%
wasserstein_distance_d(G_NN, G_NN2, t, x_intia, p=1)
# Out:
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 2.2456e+00
# L2 norm    : 5.3575e-01
# Linf norm  : 1.6135e-01
# ==============================================

# %%
wasserstein_distance_d(G_NN, G_NN2, t, x_intia, p=1)
# Out:
# === Wasserstein-p Distance Norms over Time ===
# L1 norm    : 2.9578e+00
# L2 norm    : 7.0203e-01
# Linf norm  : 2.0626e-01
# ==============================================

# %%
x = gen_x0(500, Torch=True).cpu().detach().numpy()
np.savez('data10.npz', x=x)
